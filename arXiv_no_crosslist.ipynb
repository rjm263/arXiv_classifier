# %%
import numpy as np
import pandas as pd
import math
import random

import torch
from torch.optim import AdamW
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader

from transformers import DistilBertTokenizer, DistilBertForSequenceClassification

from safetensors.torch import save_file

# %%
# Load the data in chunks and filter right away (easier on memory and time)
path = "../data_sets/arxiv-metadata-oai-snapshot.json"

columns = ["title", "abstract", "categories"]
chunks_filt = []

for chunk in pd.read_json(path, lines=True, chunksize=10000):
    chunk_filt = chunk[columns]
    chunks_filt.append(chunk_filt)

data = pd.concat(chunks_filt, ignore_index=True)

# %%
# Split the categories string into a list of single categories
data.categories = data.categories.str.split(" ")
data.head()
# Out:
#                                                title  \
# 0  Calculation of prompt diphoton production cros...
# 1           Sparsity-certifying Graph Decompositions
# 2  The evolution of the Earth-Moon system based o...
# 3  A determinant of Stirling cycle numbers counts...
# 4  From dyadic $\Lambda_{\alpha}$ to $\Lambda_{\a...
#
#                                             abstract          categories
# 0    A fully differential calculation in perturba...            [hep-ph]
# 1    We describe a new algorithm, the $(k,\ell)$-...    [math.CO, cs.CG]
# 2    The evolution of Earth-Moon system is descri...    [physics.gen-ph]
# 3    We show that a determinant of Stirling cycle...           [math.CO]
# 4    In this paper we show how to compute the $\L...  [math.CA, math.FA]

# %%
# Check for the most frequently published under categories (excluding cross-listing)
num_labels = 20
cat_ranking = data.categories.map(lambda s: s[0]).value_counts()

cats = cat_ranking.index.tolist()[:num_labels]
cat_ranking.iloc[:num_labels]
# Out:
# categories
# hep-ph                137418
# cs.CV                 122466
# quant-ph              119233
# hep-th                109071
# cs.LG                 108537
# astro-ph               94246
# gr-qc                  67256
# cond-mat.mes-hall      66164
# cs.CL                  66147
# cond-mat.mtrl-sci      65379
# math.AP                52843
# astro-ph.GA            50283
# cond-mat.str-el        50130
# math.CO                48775
# astro-ph.SR            45457
# astro-ph.HE            42273
# astro-ph.CO            42268
# cond-mat.stat-mech     42007
# math.PR                41237
# math.AG                37692
# Name: count, dtype: int64

# %%
# Just for fun: check how many papers are listed under how many different categories
data.categories.map(lambda s: len(s)).value_counts()
# Out:
# categories
# 1     1458652
# 2      829424
# 3      335912
# 4      108365
# 5       30931
# 6        6672
# 7         961
# 8         161
# 9          33
# 10         14
# 11          2
# 13          1
# Name: count, dtype: int64

# %%
# Keep only the main arXiv category for each paper (forget cross-listed ones); then only keep entries whose cat is in top 20 cats
N = 1000

data_filt = data.copy()
data_filt.categories = data_filt.categories.map(lambda x: x[0])
data_filt = data_filt[data_filt.categories.isin(cats)]

arXiv_data = data_filt.groupby('categories', group_keys=False).sample(N, random_state=3)

# %%
# Split into train/test data; here, train share is 80%
n_train = .8

train_data = arXiv_data.groupby('categories', group_keys=False).head(math.floor(n_train*N)).sample(frac=1, random_state=42)
test_data = arXiv_data.groupby('categories', group_keys=False).tail(math.ceil(N-n_train*N))

# %%
# Check that each top 20 category appear exactly 800 times
train_data.categories.value_counts()
# Out:
# categories
# cs.CV                 800
# cond-mat.mes-hall     800
# math.CO               800
# quant-ph              800
# astro-ph.GA           800
# astro-ph.SR           800
# math.AG               800
# cond-mat.str-el       800
# cond-mat.mtrl-sci     800
# astro-ph.HE           800
# math.PR               800
# hep-th                800
# hep-ph                800
# cs.CL                 800
# gr-qc                 800
# astro-ph.CO           800
# cs.LG                 800
# astro-ph              800
# cond-mat.stat-mech    800
# math.AP               800
# Name: count, dtype: int64

# %%
# Turn arXiv data into torch Dataset
class ArxivDataset(Dataset):
    def __init__(self, text, target):
        self.text = text
        self.target = target

    def __len__(self):
        return len(self.text['input_ids'])

    def __getitem__(self, idx):
        item = {key: val[idx] for key, val in self.text.items()}
        label = torch.tensor(self.target[idx], dtype=torch.long)
        return item, label

# %%
# Translate between encoded and decoded labels
label2id = {key: val for val, key in enumerate(sorted(cats))}
id2label = {val: key for key, val in label2id.items()}

# Encode labels
def label_encoder(data_frame):
    return np.array([label2id[x] for x in data_frame.categories.tolist()])

# Tokenize text input; drop abstract with probability p
def feature_encoder(data_frame, tokenize, max_len, p):
    # drop the abstract w/ prob p
    li = []
    for i, row in data_frame.iterrows():
        rd = random.random()
        if rd > p:
            li.append(f"Title: {row.title}, Abstract: {row.abstract}")
        else:
            li.append(f"Title: {row.title}, Abstract: ")

    return tokenize(
            li,
            return_tensors='pt',
            padding=True,
            truncation=True,
            max_length=max_len
        )

# %%
# Choose model data
model_name = 'distilbert-base-cased'
max_length = 512
batch_size = 8
torch.manual_seed(42)

tokenizer = DistilBertTokenizer.from_pretrained(model_name)

# %%
# Encode labels, features from our train/test datasets prepared above and convert to torch Dataset
labels = label_encoder(train_data)
features = feature_encoder(train_data, tokenizer, max_length, p=0.2)
train_sample = ArxivDataset(features, labels)
train_loader = DataLoader(train_sample, batch_size=batch_size, shuffle=True)

# %%
# For testing, choose p=1, i.e. no abstracts are included
labels = label_encoder(test_data)
features = feature_encoder(test_data, tokenizer, max_length, p=1.0)
test_sample = ArxivDataset(features, labels)
test_loader = DataLoader(test_sample, batch_size=batch_size, shuffle=True)

# %%
# To improve accuracy and time, we choose decaying learning rates: high ones for the final layers and very small ones for base layers (as we want to fine-tune)
def get_optimiser_parameters(model, base_lr, weight_decay, lr_decay=0.95):
    # Get model layers
    layers = [model.distilbert.embeddings] + list(model.distilbert.transformer.layer)
    layers.reverse()
    param_groups = []

    # Add classifier head
    param_groups.append({
        'params': model.classifier.parameters(),
        'lr': base_lr,
        'weight_decay': weight_decay
    })

    # Decay learning rate through the layers
    for i, layer in enumerate(layers):
        lr = base_lr * (lr_decay ** i)
        param_groups.append({
            'params': layer.parameters(),
            'lr': lr,
            'weight_decay': weight_decay
        })

    return param_groups

# %%
# Set up the model, loss function and optimiser (using lr decay as defined above)
model = DistilBertForSequenceClassification.from_pretrained(
    model_name,
    num_labels=num_labels,
    label2id=label2id,
    id2label=id2label
)

loss_function = nn.CrossEntropyLoss()

base_lr = 1e-5
weight_decay = 1e-2
optimiser_params = get_optimiser_parameters(model, base_lr, weight_decay)
optimiser = AdamW(optimiser_params)
# Out:
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-cased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# Training loop
n_epochs = 5

print("Training...")
model.train()
for epoch in range(n_epochs):
    epoch_loss = 0.0
    correct = 0
    number = 0

    for i, batch in enumerate(train_loader):
        print(f'Training batch {i + 1}/{len(train_loader)}')

        features, labels = batch
        optimiser.zero_grad()
        outputs = model(**features)
        logits = outputs.logits
        preds = torch.argmax(logits, dim=1)

        loss = loss_function(logits, labels)
        epoch_loss += loss.item()

        acc_labels = (labels == preds).sum().item()
        correct += acc_labels
        num_lab = labels.numel()
        number += num_lab
        acc = acc_labels / num_lab

        loss.backward()
        optimiser.step()

        print(f"Loss = {loss.item():.4f}, Acc = {acc:.4f}")

    print(f"Epoch {epoch + 1}: Loss = {epoch_loss:.4f}, Accuracy = {correct / number:.4f}")
# Out:
# Training...
# Training batch 1/2000
# Loss = 2.9883, Acc = 0.0000
# Training batch 2/2000
# Loss = 3.0597, Acc = 0.0000
# Training batch 3/2000
# Loss = 3.0383, Acc = 0.1250
# Training batch 4/2000
# Loss = 3.0437, Acc = 0.0000
# Training batch 5/2000
# Loss = 3.0591, Acc = 0.0000
# Training batch 6/2000
# Loss = 3.0272, Acc = 0.0000
# Training batch 7/2000
# Loss = 3.0201, Acc = 0.0000
# Training batch 8/2000
# Loss = 3.0190, Acc = 0.0000
# Training batch 9/2000
# Loss = 3.0559, Acc = 0.0000
# Training batch 10/2000
# Loss = 3.0070, Acc = 0.1250
# Training batch 11/2000
# Loss = 3.0687, Acc = 0.0000
# Training batch 12/2000
# Loss = 3.0282, Acc = 0.0000
# Training batch 13/2000
# Loss = 2.9158, Acc = 0.1250
# Training batch 14/2000
# Loss = 2.9222, Acc = 0.1250
# Training batch 15/2000
# Loss = 3.0397, Acc = 0.0000
# Training batch 16/2000
# Loss = 3.0425, Acc = 0.0000
# Training batch 17/2000
# Loss = 3.0083, Acc = 0.0000
# Training batch 18/2000
# Loss = 2.9627, Acc = 0.0000
# Training batch 19/2000
# Loss = 2.9601, Acc = 0.1250
# Training batch 20/2000
# Loss = 2.9545, Acc = 0.0000
# Training batch 21/2000
# Loss = 2.9253, Acc = 0.2500
# Training batch 22/2000
# Loss = 2.9911, Acc = 0.0000
# Training batch 23/2000
# Loss = 3.0572, Acc = 0.0000
# Training batch 24/2000
# Loss = 3.0331, Acc = 0.0000
# Training batch 25/2000
# Loss = 2.9714, Acc = 0.1250
# Training batch 26/2000
# Loss = 2.9376, Acc = 0.0000
# Training batch 27/2000
# Loss = 2.9398, Acc = 0.0000
# Training batch 28/2000
# Loss = 2.9800, Acc = 0.1250
# Training batch 29/2000
# Loss = 2.9909, Acc = 0.0000
# Training batch 30/2000
# Loss = 3.0224, Acc = 0.0000
# Training batch 31/2000
# Loss = 2.9931, Acc = 0.1250
# Training batch 32/2000
# Loss = 2.9515, Acc = 0.1250
# Training batch 33/2000
# Loss = 2.9420, Acc = 0.2500
# Training batch 34/2000
# Loss = 2.9102, Acc = 0.0000
# Training batch 35/2000
# Loss = 3.0672, Acc = 0.1250
# Training batch 36/2000
# Loss = 2.9636, Acc = 0.0000
# Training batch 37/2000
# Loss = 2.9789, Acc = 0.1250
# Training batch 38/2000
# Loss = 3.0192, Acc = 0.1250
# Training batch 39/2000
# Loss = 3.1063, Acc = 0.0000
# Training batch 40/2000
# Loss = 2.9413, Acc = 0.1250
# Training batch 41/2000
# Loss = 2.9270, Acc = 0.2500
# Training batch 42/2000
# Loss = 2.8952, Acc = 0.2500
# Training batch 43/2000
# Loss = 3.0281, Acc = 0.1250
# Training batch 44/2000
# Loss = 2.9142, Acc = 0.1250
# Training batch 45/2000
# Loss = 3.0335, Acc = 0.0000
# Training batch 46/2000
# Loss = 2.9319, Acc = 0.1250
# Training batch 47/2000
# Loss = 2.9107, Acc = 0.2500
# Training batch 48/2000
# Loss = 2.9599, Acc = 0.2500
# Training batch 49/2000
# Loss = 2.9979, Acc = 0.1250
# Training batch 50/2000
# Loss = 2.9288, Acc = 0.0000
# Training batch 51/2000
# Loss = 2.9537, Acc = 0.1250
# Training batch 52/2000
# Loss = 3.0299, Acc = 0.0000
# Training batch 53/2000
# Loss = 2.9990, Acc = 0.0000
# Training batch 54/2000
# Loss = 3.0090, Acc = 0.0000
# Training batch 55/2000
# Loss = 2.9989, Acc = 0.1250
# Training batch 56/2000
# Loss = 3.0063, Acc = 0.0000
# Training batch 57/2000
# Loss = 2.9686, Acc = 0.1250
# Training batch 58/2000
# Loss = 2.9000, Acc = 0.1250
# Training batch 59/2000
# Loss = 2.9679, Acc = 0.0000
# Training batch 60/2000
# Loss = 2.8800, Acc = 0.1250
# Training batch 61/2000
# Loss = 2.9846, Acc = 0.0000
# Training batch 62/2000
# Loss = 2.9214, Acc = 0.0000
# Training batch 63/2000
# Loss = 2.9870, Acc = 0.1250
# Training batch 64/2000
# Loss = 3.0034, Acc = 0.0000
# Training batch 65/2000
# Loss = 2.8300, Acc = 0.2500
# Training batch 66/2000
# Loss = 2.9512, Acc = 0.2500
# Training batch 67/2000
# Loss = 2.9065, Acc = 0.1250
# Training batch 68/2000
# Loss = 2.9863, Acc = 0.0000
# Training batch 69/2000
# Loss = 3.0313, Acc = 0.0000
# Training batch 70/2000
# Loss = 2.9810, Acc = 0.0000
# Training batch 71/2000
# Loss = 3.0488, Acc = 0.0000
# Training batch 72/2000
# Loss = 2.9030, Acc = 0.1250
# Training batch 73/2000
# Loss = 2.8415, Acc = 0.3750
# Training batch 74/2000
# Loss = 2.9148, Acc = 0.2500
# Training batch 75/2000
# Loss = 2.9640, Acc = 0.1250
# Training batch 76/2000
# Loss = 2.8979, Acc = 0.1250
# Training batch 77/2000
# Loss = 2.9334, Acc = 0.2500
# Training batch 78/2000
# Loss = 3.0098, Acc = 0.1250
# Training batch 79/2000
# Loss = 2.9294, Acc = 0.0000
# Training batch 80/2000
# Loss = 2.9487, Acc = 0.0000
# Training batch 81/2000
# Loss = 2.8974, Acc = 0.1250
# Training batch 82/2000
# Loss = 2.9968, Acc = 0.0000
# Training batch 83/2000
# Loss = 2.8672, Acc = 0.1250
# Training batch 84/2000
# Loss = 2.9286, Acc = 0.1250
# Training batch 85/2000
# Loss = 2.8388, Acc = 0.3750
# Training batch 86/2000
# Loss = 2.8838, Acc = 0.1250
# Training batch 87/2000
# Loss = 2.9782, Acc = 0.0000
# Training batch 88/2000
# Loss = 2.9065, Acc = 0.0000
# Training batch 89/2000
# Loss = 2.8823, Acc = 0.3750
# Training batch 90/2000
# Loss = 2.8484, Acc = 0.1250
# Training batch 91/2000
# Loss = 2.9114, Acc = 0.1250
# Training batch 92/2000
# Loss = 2.8798, Acc = 0.0000
# Training batch 93/2000
# Loss = 2.8876, Acc = 0.1250
# Training batch 94/2000
# Loss = 2.7669, Acc = 0.2500
# Training batch 95/2000
# Loss = 2.6603, Acc = 0.3750
# Training batch 96/2000
# Loss = 2.7630, Acc = 0.2500
# Training batch 97/2000
# Loss = 2.7156, Acc = 0.3750
# Training batch 98/2000
# Loss = 2.7768, Acc = 0.1250
# Training batch 99/2000
# Loss = 2.8023, Acc = 0.1250
# Training batch 100/2000
# Loss = 2.7555, Acc = 0.2500
# Training batch 101/2000
# Loss = 2.8862, Acc = 0.0000
# Training batch 102/2000
# Loss = 2.8594, Acc = 0.0000
# Training batch 103/2000
# Loss = 2.8946, Acc = 0.0000
# Training batch 104/2000
# Loss = 2.7386, Acc = 0.1250
# Training batch 105/2000
# Loss = 2.7521, Acc = 0.3750
# Training batch 106/2000
# Loss = 2.8539, Acc = 0.0000
# Training batch 107/2000
# Loss = 2.7313, Acc = 0.2500
# Training batch 108/2000
# Loss = 2.7560, Acc = 0.3750
# Training batch 109/2000
# Loss = 2.7861, Acc = 0.2500
# Training batch 110/2000
# Loss = 2.7366, Acc = 0.1250
# Training batch 111/2000
# Loss = 2.6951, Acc = 0.1250
# Training batch 112/2000
# Loss = 2.7060, Acc = 0.2500
# Training batch 113/2000
# Loss = 2.7363, Acc = 0.2500
# Training batch 114/2000
# Loss = 2.7598, Acc = 0.1250
# Training batch 115/2000
# Loss = 2.6050, Acc = 0.1250
# Training batch 116/2000
# Loss = 2.7990, Acc = 0.2500
# Training batch 117/2000
# Loss = 2.7187, Acc = 0.5000
# Training batch 118/2000
# Loss = 2.6816, Acc = 0.2500
# Training batch 119/2000
# Loss = 2.6927, Acc = 0.2500
# Training batch 120/2000
# Loss = 2.7401, Acc = 0.1250
# Training batch 121/2000
# Loss = 2.7720, Acc = 0.2500
# Training batch 122/2000
# Loss = 2.6750, Acc = 0.1250
# Training batch 123/2000
# Loss = 2.8854, Acc = 0.1250
# Training batch 124/2000
# Loss = 2.8188, Acc = 0.0000
# Training batch 125/2000
# Loss = 2.6944, Acc = 0.3750
# Training batch 126/2000
# Loss = 2.7796, Acc = 0.0000
# Training batch 127/2000
# Loss = 2.5681, Acc = 0.1250
# Training batch 128/2000
# Loss = 2.6769, Acc = 0.2500
# Training batch 129/2000
# Loss = 2.7544, Acc = 0.1250
# Training batch 130/2000
# Loss = 2.6816, Acc = 0.3750
# Training batch 131/2000
# Loss = 2.6276, Acc = 0.1250
# Training batch 132/2000
# Loss = 2.7922, Acc = 0.1250
# Training batch 133/2000
# Loss = 2.7532, Acc = 0.1250
# Training batch 134/2000
# Loss = 2.7626, Acc = 0.1250
# Training batch 135/2000
# Loss = 2.8370, Acc = 0.1250
# Training batch 136/2000
# Loss = 2.7630, Acc = 0.0000
# Training batch 137/2000
# Loss = 2.7030, Acc = 0.0000
# Training batch 138/2000
# Loss = 2.6710, Acc = 0.2500
# Training batch 139/2000
# Loss = 2.6414, Acc = 0.2500
# Training batch 140/2000
# Loss = 2.6146, Acc = 0.6250
# Training batch 141/2000
# Loss = 2.6425, Acc = 0.2500
# Training batch 142/2000
# Loss = 2.7058, Acc = 0.1250
# Training batch 143/2000
# Loss = 2.5332, Acc = 0.2500
# Training batch 144/2000
# Loss = 2.6778, Acc = 0.3750
# Training batch 145/2000
# Loss = 2.6296, Acc = 0.2500
# Training batch 146/2000
# Loss = 2.6215, Acc = 0.2500
# Training batch 147/2000
# Loss = 2.6401, Acc = 0.2500
# Training batch 148/2000
# Loss = 2.7850, Acc = 0.0000
# Training batch 149/2000
# Loss = 2.6420, Acc = 0.1250
# Training batch 150/2000
# Loss = 2.4973, Acc = 0.0000
# Training batch 151/2000
# Loss = 2.7078, Acc = 0.1250
# Training batch 152/2000
# Loss = 2.6083, Acc = 0.2500
# Training batch 153/2000
# Loss = 2.4115, Acc = 0.7500
# Training batch 154/2000
# Loss = 2.5569, Acc = 0.2500
# Training batch 155/2000
# Loss = 2.3886, Acc = 0.5000
# Training batch 156/2000
# Loss = 2.6572, Acc = 0.1250
# Training batch 157/2000
# Loss = 2.5319, Acc = 0.2500
# Training batch 158/2000
# Loss = 2.5950, Acc = 0.2500
# Training batch 159/2000
# Loss = 2.7348, Acc = 0.1250
# Training batch 160/2000
# Loss = 2.5062, Acc = 0.3750
# Training batch 161/2000
# Loss = 2.4430, Acc = 0.3750
# Training batch 162/2000
# Loss = 2.4584, Acc = 0.3750
# Training batch 163/2000
# Loss = 2.6420, Acc = 0.1250
# Training batch 164/2000
# Loss = 2.6482, Acc = 0.2500
# Training batch 165/2000
# Loss = 2.5790, Acc = 0.2500
# Training batch 166/2000
# Loss = 2.5154, Acc = 0.2500
# Training batch 167/2000
# Loss = 2.3777, Acc = 0.5000
# Training batch 168/2000
# Loss = 2.8677, Acc = 0.0000
# Training batch 169/2000
# Loss = 2.6246, Acc = 0.1250
# Training batch 170/2000
# Loss = 2.4769, Acc = 0.5000
# Training batch 171/2000
# Loss = 2.6683, Acc = 0.0000
# Training batch 172/2000
# Loss = 2.5911, Acc = 0.2500
# Training batch 173/2000
# Loss = 2.4557, Acc = 0.5000
# Training batch 174/2000
# Loss = 2.6250, Acc = 0.3750
# Training batch 175/2000
# Loss = 2.3735, Acc = 0.2500
# Training batch 176/2000
# Loss = 2.3856, Acc = 0.5000
# Training batch 177/2000
# Loss = 2.6843, Acc = 0.1250
# Training batch 178/2000
# Loss = 2.5969, Acc = 0.0000
# Training batch 179/2000
# Loss = 2.2250, Acc = 0.5000
# Training batch 180/2000
# Loss = 2.3545, Acc = 0.2500
# Training batch 181/2000
# Loss = 2.4073, Acc = 0.2500
# Training batch 182/2000
# Loss = 2.4982, Acc = 0.3750
# Training batch 183/2000
# Loss = 2.5335, Acc = 0.2500
# Training batch 184/2000
# Loss = 2.2959, Acc = 0.2500
# Training batch 185/2000
# Loss = 2.2721, Acc = 0.5000
# Training batch 186/2000
# Loss = 2.5899, Acc = 0.1250
# Training batch 187/2000
# Loss = 2.6793, Acc = 0.0000
# Training batch 188/2000
# Loss = 2.6768, Acc = 0.0000
# Training batch 189/2000
# Loss = 2.4844, Acc = 0.1250
# Training batch 190/2000
# Loss = 2.4677, Acc = 0.2500
# Training batch 191/2000
# Loss = 2.2896, Acc = 0.2500
# Training batch 192/2000
# Loss = 2.4877, Acc = 0.2500
# Training batch 193/2000
# Loss = 2.1806, Acc = 0.6250
# Training batch 194/2000
# Loss = 2.3518, Acc = 0.1250
# Training batch 195/2000
# Loss = 2.3550, Acc = 0.2500
# Training batch 196/2000
# Loss = 2.3765, Acc = 0.2500
# Training batch 197/2000
# Loss = 2.5925, Acc = 0.1250
# Training batch 198/2000
# Loss = 2.5422, Acc = 0.0000
# Training batch 199/2000
# Loss = 2.4220, Acc = 0.3750
# Training batch 200/2000
# Loss = 2.3825, Acc = 0.2500
# Training batch 201/2000
# Loss = 2.6461, Acc = 0.2500
# Training batch 202/2000
# Loss = 2.3095, Acc = 0.3750
# Training batch 203/2000
# Loss = 2.5394, Acc = 0.2500
# Training batch 204/2000
# Loss = 2.4957, Acc = 0.0000
# Training batch 205/2000
# Loss = 2.4885, Acc = 0.2500
# Training batch 206/2000
# Loss = 2.5990, Acc = 0.0000
# Training batch 207/2000
# Loss = 2.4168, Acc = 0.3750
# Training batch 208/2000
# Loss = 2.6455, Acc = 0.2500
# Training batch 209/2000
# Loss = 2.5345, Acc = 0.2500
# Training batch 210/2000
# Loss = 2.5159, Acc = 0.2500
# Training batch 211/2000
# Loss = 2.4460, Acc = 0.2500
# Training batch 212/2000
# Loss = 2.3360, Acc = 0.2500
# Training batch 213/2000
# Loss = 2.4032, Acc = 0.3750
# Training batch 214/2000
# Loss = 2.4279, Acc = 0.2500
# Training batch 215/2000
# Loss = 2.3493, Acc = 0.1250
# Training batch 216/2000
# Loss = 2.3994, Acc = 0.0000
# Training batch 217/2000
# Loss = 2.2602, Acc = 0.2500
# Training batch 218/2000
# Loss = 2.2540, Acc = 0.3750
# Training batch 219/2000
# Loss = 2.3394, Acc = 0.5000
# Training batch 220/2000
# Loss = 2.4377, Acc = 0.2500
# Training batch 221/2000
# Loss = 2.3261, Acc = 0.5000
# Training batch 222/2000
# Loss = 2.2990, Acc = 0.2500
# Training batch 223/2000
# Loss = 2.5276, Acc = 0.0000
# Training batch 224/2000
# Loss = 2.1134, Acc = 0.6250
# Training batch 225/2000
# Loss = 2.3441, Acc = 0.1250
# Training batch 226/2000
# Loss = 2.1961, Acc = 0.5000
# Training batch 227/2000
# Loss = 1.9716, Acc = 0.5000
# Training batch 228/2000
# Loss = 2.4527, Acc = 0.3750
# Training batch 229/2000
# Loss = 2.2711, Acc = 0.2500
# Training batch 230/2000
# Loss = 2.4574, Acc = 0.2500
# Training batch 231/2000
# Loss = 2.6189, Acc = 0.1250
# Training batch 232/2000
# Loss = 2.3377, Acc = 0.5000
# Training batch 233/2000
# Loss = 2.2276, Acc = 0.1250
# Training batch 234/2000
# Loss = 2.2313, Acc = 0.5000
# Training batch 235/2000
# Loss = 2.3059, Acc = 0.1250
# Training batch 236/2000
# Loss = 2.0894, Acc = 0.7500
# Training batch 237/2000
# Loss = 2.2122, Acc = 0.5000
# Training batch 238/2000
# Loss = 2.3042, Acc = 0.2500
# Training batch 239/2000
# Loss = 2.3477, Acc = 0.3750
# Training batch 240/2000
# Loss = 2.4802, Acc = 0.2500
# Training batch 241/2000
# Loss = 2.5071, Acc = 0.2500
# Training batch 242/2000
# Loss = 2.1700, Acc = 0.8750
# Training batch 243/2000
# Loss = 2.5846, Acc = 0.2500
# Training batch 244/2000
# Loss = 2.3923, Acc = 0.5000
# Training batch 245/2000
# Loss = 2.6293, Acc = 0.1250
# Training batch 246/2000
# Loss = 2.2678, Acc = 0.6250
# Training batch 247/2000
# Loss = 2.3194, Acc = 0.3750
# Training batch 248/2000
# Loss = 2.4510, Acc = 0.1250
# Training batch 249/2000
# Loss = 2.4377, Acc = 0.2500
# Training batch 250/2000
# Loss = 2.2235, Acc = 0.2500
# Training batch 251/2000
# Loss = 2.3778, Acc = 0.2500
# Training batch 252/2000
# Loss = 2.1171, Acc = 0.6250
# Training batch 253/2000
# Loss = 2.3347, Acc = 0.0000
# Training batch 254/2000
# Loss = 2.3589, Acc = 0.2500
# Training batch 255/2000
# Loss = 2.4221, Acc = 0.1250
# Training batch 256/2000
# Loss = 2.5135, Acc = 0.1250
# Training batch 257/2000
# Loss = 2.1749, Acc = 0.2500
# Training batch 258/2000
# Loss = 2.4705, Acc = 0.3750
# Training batch 259/2000
# Loss = 2.5326, Acc = 0.1250
# Training batch 260/2000
# Loss = 2.2581, Acc = 0.3750
# Training batch 261/2000
# Loss = 2.3152, Acc = 0.1250
# Training batch 262/2000
# Loss = 2.4478, Acc = 0.3750
# Training batch 263/2000
# Loss = 2.0525, Acc = 0.5000
# Training batch 264/2000
# Loss = 2.2397, Acc = 0.2500
# Training batch 265/2000
# Loss = 2.1561, Acc = 0.3750
# Training batch 266/2000
# Loss = 2.3227, Acc = 0.2500
# Training batch 267/2000
# Loss = 2.2049, Acc = 0.3750
# Training batch 268/2000
# Loss = 2.1616, Acc = 0.5000
# Training batch 269/2000
# Loss = 2.3413, Acc = 0.2500
# Training batch 270/2000
# Loss = 2.3582, Acc = 0.2500
# Training batch 271/2000
# Loss = 1.9614, Acc = 0.5000
# Training batch 272/2000
# Loss = 2.2464, Acc = 0.5000
# Training batch 273/2000
# Loss = 2.4743, Acc = 0.2500
# Training batch 274/2000
# Loss = 2.1913, Acc = 0.3750
# Training batch 275/2000
# Loss = 2.1778, Acc = 0.2500
# Training batch 276/2000
# Loss = 2.1543, Acc = 0.3750
# Training batch 277/2000
# Loss = 2.2851, Acc = 0.5000
# Training batch 278/2000
# Loss = 2.4214, Acc = 0.2500
# Training batch 279/2000
# Loss = 2.0589, Acc = 0.6250
# Training batch 280/2000
# Loss = 1.7169, Acc = 0.5000
# Training batch 281/2000
# Loss = 2.0557, Acc = 0.5000
# Training batch 282/2000
# Loss = 2.3653, Acc = 0.2500
# Training batch 283/2000
# Loss = 2.4292, Acc = 0.1250
# Training batch 284/2000
# Loss = 2.2898, Acc = 0.5000
# Training batch 285/2000
# Loss = 2.1233, Acc = 0.5000
# Training batch 286/2000
# Loss = 2.1120, Acc = 0.3750
# Training batch 287/2000
# Loss = 2.0667, Acc = 0.5000
# Training batch 288/2000
# Loss = 1.9642, Acc = 0.5000
# Training batch 289/2000
# Loss = 2.1813, Acc = 0.5000
# Training batch 290/2000
# Loss = 2.1844, Acc = 0.3750
# Training batch 291/2000
# Loss = 2.2595, Acc = 0.3750
# Training batch 292/2000
# Loss = 2.4061, Acc = 0.1250
# Training batch 293/2000
# Loss = 2.1977, Acc = 0.6250
# Training batch 294/2000
# Loss = 2.2095, Acc = 0.2500
# Training batch 295/2000
# Loss = 2.0025, Acc = 0.5000
# Training batch 296/2000
# Loss = 2.2057, Acc = 0.3750
# Training batch 297/2000
# Loss = 2.1602, Acc = 0.2500
# Training batch 298/2000
# Loss = 2.0841, Acc = 0.3750
# Training batch 299/2000
# Loss = 2.0775, Acc = 0.5000
# Training batch 300/2000
# Loss = 2.3062, Acc = 0.2500
# Training batch 301/2000
# Loss = 1.9075, Acc = 0.7500
# Training batch 302/2000
# Loss = 2.2221, Acc = 0.2500
# Training batch 303/2000
# Loss = 2.2270, Acc = 0.2500
# Training batch 304/2000
# Loss = 2.2485, Acc = 0.3750
# Training batch 305/2000
# Loss = 2.1074, Acc = 0.3750
# Training batch 306/2000
# Loss = 2.1822, Acc = 0.6250
# Training batch 307/2000
# Loss = 2.2023, Acc = 0.2500
# Training batch 308/2000
# Loss = 2.3789, Acc = 0.2500
# Training batch 309/2000
# Loss = 2.2526, Acc = 0.2500
# Training batch 310/2000
# Loss = 2.5353, Acc = 0.1250
# Training batch 311/2000
# Loss = 2.2876, Acc = 0.3750
# Training batch 312/2000
# Loss = 1.9619, Acc = 0.7500
# Training batch 313/2000
# Loss = 2.0883, Acc = 0.5000
# Training batch 314/2000
# Loss = 2.2551, Acc = 0.3750
# Training batch 315/2000
# Loss = 2.1237, Acc = 0.1250
# Training batch 316/2000
# Loss = 2.5388, Acc = 0.2500
# Training batch 317/2000
# Loss = 2.2484, Acc = 0.1250
# Training batch 318/2000
# Loss = 1.8193, Acc = 0.3750
# Training batch 319/2000
# Loss = 2.2519, Acc = 0.3750
# Training batch 320/2000
# Loss = 2.2677, Acc = 0.3750
# Training batch 321/2000
# Loss = 2.0089, Acc = 0.2500
# Training batch 322/2000
# Loss = 2.3691, Acc = 0.1250
# Training batch 323/2000
# Loss = 2.3431, Acc = 0.2500
# Training batch 324/2000
# Loss = 2.1174, Acc = 0.3750
# Training batch 325/2000
# Loss = 2.1680, Acc = 0.1250
# Training batch 326/2000
# Loss = 1.8078, Acc = 0.6250
# Training batch 327/2000
# Loss = 2.0832, Acc = 0.3750
# Training batch 328/2000
# Loss = 2.3599, Acc = 0.1250
# Training batch 329/2000
# Loss = 2.1982, Acc = 0.2500
# Training batch 330/2000
# Loss = 2.3332, Acc = 0.1250
# Training batch 331/2000
# Loss = 2.0532, Acc = 0.3750
# Training batch 332/2000
# Loss = 2.1472, Acc = 0.5000
# Training batch 333/2000
# Loss = 2.1789, Acc = 0.2500
# Training batch 334/2000
# Loss = 2.2372, Acc = 0.3750
# Training batch 335/2000
# Loss = 2.2032, Acc = 0.2500
# Training batch 336/2000
# Loss = 2.2712, Acc = 0.3750
# Training batch 337/2000
# Loss = 2.3284, Acc = 0.3750
# Training batch 338/2000
# Loss = 2.0835, Acc = 0.3750
# Training batch 339/2000
# Loss = 2.1595, Acc = 0.3750
# Training batch 340/2000
# Loss = 2.2785, Acc = 0.3750
# Training batch 341/2000
# Loss = 1.8100, Acc = 0.7500
# Training batch 342/2000
# Loss = 2.2904, Acc = 0.3750
# Training batch 343/2000
# Loss = 2.4437, Acc = 0.2500
# Training batch 344/2000
# Loss = 2.1657, Acc = 0.3750
# Training batch 345/2000
# Loss = 2.1374, Acc = 0.5000
# Training batch 346/2000
# Loss = 2.4146, Acc = 0.0000
# Training batch 347/2000
# Loss = 2.1311, Acc = 0.6250
# Training batch 348/2000
# Loss = 2.0739, Acc = 0.5000
# Training batch 349/2000
# Loss = 1.9986, Acc = 0.2500
# Training batch 350/2000
# Loss = 1.9657, Acc = 0.3750
# Training batch 351/2000
# Loss = 1.9743, Acc = 0.5000
# Training batch 352/2000
# Loss = 2.0694, Acc = 0.6250
# Training batch 353/2000
# Loss = 2.1395, Acc = 0.5000
# Training batch 354/2000
# Loss = 1.9890, Acc = 0.5000
# Training batch 355/2000
# Loss = 2.2811, Acc = 0.1250
# Training batch 356/2000
# Loss = 2.1549, Acc = 0.5000
# Training batch 357/2000
# Loss = 1.9988, Acc = 0.3750
# Training batch 358/2000
# Loss = 2.1467, Acc = 0.2500
# Training batch 359/2000
# Loss = 2.0100, Acc = 0.3750
# Training batch 360/2000
# Loss = 2.1648, Acc = 0.2500
# Training batch 361/2000
# Loss = 2.0715, Acc = 0.5000
# Training batch 362/2000
# Loss = 2.3425, Acc = 0.1250
# Training batch 363/2000
# Loss = 1.8959, Acc = 0.5000
# Training batch 364/2000
# Loss = 2.2001, Acc = 0.2500
# Training batch 365/2000
# Loss = 1.7883, Acc = 0.3750
# Training batch 366/2000
# Loss = 2.0741, Acc = 0.3750
# Training batch 367/2000
# Loss = 2.0119, Acc = 0.5000
# Training batch 368/2000
# Loss = 2.3598, Acc = 0.1250
# Training batch 369/2000
# Loss = 1.9259, Acc = 0.7500
# Training batch 370/2000
# Loss = 2.1690, Acc = 0.5000
# Training batch 371/2000
# Loss = 1.8243, Acc = 0.7500
# Training batch 372/2000
# Loss = 2.0938, Acc = 0.6250
# Training batch 373/2000
# Loss = 2.0504, Acc = 0.3750
# Training batch 374/2000
# Loss = 2.0674, Acc = 0.5000
# Training batch 375/2000
# Loss = 1.9737, Acc = 0.5000
# Training batch 376/2000
# Loss = 1.9971, Acc = 0.2500
# Training batch 377/2000
# Loss = 2.4062, Acc = 0.1250
# Training batch 378/2000
# Loss = 2.0624, Acc = 0.3750
# Training batch 379/2000
# Loss = 2.1265, Acc = 0.3750
# Training batch 380/2000
# Loss = 2.0589, Acc = 0.6250
# Training batch 381/2000
# Loss = 2.3905, Acc = 0.3750
# Training batch 382/2000
# Loss = 1.9360, Acc = 0.6250
# Training batch 383/2000
# Loss = 2.1279, Acc = 0.3750
# Training batch 384/2000
# Loss = 1.9838, Acc = 0.5000
# Training batch 385/2000
# Loss = 2.1454, Acc = 0.6250
# Training batch 386/2000
# Loss = 1.6122, Acc = 0.8750
# Training batch 387/2000
# Loss = 1.8911, Acc = 0.6250
# Training batch 388/2000
# Loss = 1.8544, Acc = 0.6250
# Training batch 389/2000
# Loss = 2.0700, Acc = 0.3750
# Training batch 390/2000
# Loss = 2.1147, Acc = 0.3750
# Training batch 391/2000
# Loss = 2.0286, Acc = 0.3750
# Training batch 392/2000
# Loss = 1.7642, Acc = 0.7500
# Training batch 393/2000
# Loss = 1.9811, Acc = 0.5000
# Training batch 394/2000
# Loss = 2.0447, Acc = 0.6250
# Training batch 395/2000
# Loss = 1.8930, Acc = 0.3750
# Training batch 396/2000
# Loss = 2.3953, Acc = 0.5000
# Training batch 397/2000
# Loss = 2.0435, Acc = 0.5000
# Training batch 398/2000
# Loss = 2.1488, Acc = 0.5000
# Training batch 399/2000
# Loss = 1.8732, Acc = 0.3750
# Training batch 400/2000
# Loss = 2.0062, Acc = 0.6250
# Training batch 401/2000
# Loss = 1.9682, Acc = 0.3750
# Training batch 402/2000
# Loss = 2.0694, Acc = 0.2500
# Training batch 403/2000
# Loss = 2.1846, Acc = 0.2500
# Training batch 404/2000
# Loss = 2.0583, Acc = 0.3750
# Training batch 405/2000
# Loss = 1.9489, Acc = 0.7500
# Training batch 406/2000
# Loss = 2.1570, Acc = 0.3750
# Training batch 407/2000
# Loss = 2.0959, Acc = 0.2500
# Training batch 408/2000
# Loss = 2.3112, Acc = 0.1250
# Training batch 409/2000
# Loss = 1.7804, Acc = 0.6250
# Training batch 410/2000
# Loss = 2.1763, Acc = 0.3750
# Training batch 411/2000
# Loss = 1.6967, Acc = 0.7500
# Training batch 412/2000
# Loss = 1.8474, Acc = 0.6250
# Training batch 413/2000
# Loss = 1.9110, Acc = 0.7500
# Training batch 414/2000
# Loss = 2.0297, Acc = 0.1250
# Training batch 415/2000
# Loss = 2.1710, Acc = 0.3750
# Training batch 416/2000
# Loss = 2.0068, Acc = 0.5000
# Training batch 417/2000
# Loss = 2.0643, Acc = 0.3750
# Training batch 418/2000
# Loss = 2.1549, Acc = 0.3750
# Training batch 419/2000
# Loss = 1.9466, Acc = 0.5000
# Training batch 420/2000
# Loss = 2.1112, Acc = 0.6250
# Training batch 421/2000
# Loss = 2.0423, Acc = 0.5000
# Training batch 422/2000
# Loss = 1.8812, Acc = 0.7500
# Training batch 423/2000
# Loss = 1.7887, Acc = 0.5000
# Training batch 424/2000
# Loss = 1.9818, Acc = 0.7500
# Training batch 425/2000
# Loss = 1.9301, Acc = 0.3750
# Training batch 426/2000
# Loss = 2.2368, Acc = 0.3750
# Training batch 427/2000
# Loss = 2.0421, Acc = 0.6250
# Training batch 428/2000
# Loss = 1.7596, Acc = 0.6250
# Training batch 429/2000
# Loss = 2.0692, Acc = 0.2500
# Training batch 430/2000
# Loss = 2.2001, Acc = 0.2500
# Training batch 431/2000
# Loss = 1.9984, Acc = 0.2500
# Training batch 432/2000
# Loss = 1.5319, Acc = 0.7500
# Training batch 433/2000
# Loss = 2.1573, Acc = 0.6250
# Training batch 434/2000
# Loss = 2.1690, Acc = 0.2500
# Training batch 435/2000
# Loss = 1.8227, Acc = 0.5000
# Training batch 436/2000
# Loss = 1.9523, Acc = 0.5000
# Training batch 437/2000
# Loss = 1.8527, Acc = 0.7500
# Training batch 438/2000
# Loss = 2.0849, Acc = 0.1250
# Training batch 439/2000
# Loss = 1.8081, Acc = 0.6250
# Training batch 440/2000
# Loss = 2.0723, Acc = 0.3750
# Training batch 441/2000
# Loss = 2.0850, Acc = 0.5000
# Training batch 442/2000
# Loss = 1.9611, Acc = 0.3750
# Training batch 443/2000
# Loss = 2.2560, Acc = 0.3750
# Training batch 444/2000
# Loss = 1.5860, Acc = 0.7500
# Training batch 445/2000
# Loss = 2.0462, Acc = 0.3750
# Training batch 446/2000
# Loss = 1.7578, Acc = 0.6250
# Training batch 447/2000
# Loss = 2.1633, Acc = 0.1250
# Training batch 448/2000
# Loss = 1.8086, Acc = 0.3750
# Training batch 449/2000
# Loss = 1.9777, Acc = 0.3750
# Training batch 450/2000
# Loss = 1.9653, Acc = 0.6250
# Training batch 451/2000
# Loss = 2.0238, Acc = 0.2500
# Training batch 452/2000
# Loss = 1.8519, Acc = 0.6250
# Training batch 453/2000
# Loss = 1.8726, Acc = 0.5000
# Training batch 454/2000
# Loss = 2.0250, Acc = 0.3750
# Training batch 455/2000
# Loss = 1.7313, Acc = 0.8750
# Training batch 456/2000
# Loss = 1.9699, Acc = 0.3750
# Training batch 457/2000
# Loss = 1.6788, Acc = 0.7500
# Training batch 458/2000
# Loss = 1.8495, Acc = 0.6250
# Training batch 459/2000
# Loss = 2.0864, Acc = 0.5000
# Training batch 460/2000
# Loss = 1.7438, Acc = 0.5000
# Training batch 461/2000
# Loss = 2.0656, Acc = 0.3750
# Training batch 462/2000
# Loss = 1.9675, Acc = 0.5000
# Training batch 463/2000
# Loss = 1.7756, Acc = 0.7500
# Training batch 464/2000
# Loss = 1.9119, Acc = 0.6250
# Training batch 465/2000
# Loss = 2.0002, Acc = 0.5000
# Training batch 466/2000
# Loss = 2.0875, Acc = 0.5000
# Training batch 467/2000
# Loss = 1.6050, Acc = 0.7500
# Training batch 468/2000
# Loss = 1.8485, Acc = 0.5000
# Training batch 469/2000
# Loss = 2.0930, Acc = 0.5000
# Training batch 470/2000
# Loss = 2.0710, Acc = 0.1250
# Training batch 471/2000
# Loss = 1.9921, Acc = 0.2500
# Training batch 472/2000
# Loss = 1.9694, Acc = 0.3750
# Training batch 473/2000
# Loss = 1.8319, Acc = 0.5000
# Training batch 474/2000
# Loss = 2.0179, Acc = 0.5000
# Training batch 475/2000
# Loss = 2.2933, Acc = 0.1250
# Training batch 476/2000
# Loss = 1.8788, Acc = 0.5000
# Training batch 477/2000
# Loss = 2.0826, Acc = 0.5000
# Training batch 478/2000
# Loss = 1.9292, Acc = 0.3750
# Training batch 479/2000
# Loss = 1.7587, Acc = 0.6250
# Training batch 480/2000
# Loss = 2.1255, Acc = 0.5000
# Training batch 481/2000
# Loss = 1.9505, Acc = 0.6250
# Training batch 482/2000
# Loss = 1.8268, Acc = 0.6250
# Training batch 483/2000
# Loss = 1.9127, Acc = 0.3750
# Training batch 484/2000
# Loss = 1.9535, Acc = 0.6250
# Training batch 485/2000
# Loss = 1.9394, Acc = 0.6250
# Training batch 486/2000
# Loss = 1.9272, Acc = 0.3750
# Training batch 487/2000
# Loss = 1.8833, Acc = 0.5000
# Training batch 488/2000
# Loss = 1.8585, Acc = 0.5000
# Training batch 489/2000
# Loss = 1.9771, Acc = 0.3750
# Training batch 490/2000
# Loss = 1.7093, Acc = 0.7500
# Training batch 491/2000
# Loss = 1.7485, Acc = 0.5000
# Training batch 492/2000
# Loss = 2.1200, Acc = 0.1250
# Training batch 493/2000
# Loss = 2.1660, Acc = 0.1250
# Training batch 494/2000
# Loss = 1.6313, Acc = 0.6250
# Training batch 495/2000
# Loss = 1.7377, Acc = 0.5000
# Training batch 496/2000
# Loss = 1.9349, Acc = 0.3750
# Training batch 497/2000
# Loss = 2.2546, Acc = 0.0000
# Training batch 498/2000
# Loss = 2.2658, Acc = 0.3750
# Training batch 499/2000
# Loss = 1.7635, Acc = 0.8750
# Training batch 500/2000
# Loss = 1.9308, Acc = 0.3750
# Training batch 501/2000
# Loss = 2.0885, Acc = 0.3750
# Training batch 502/2000
# Loss = 1.8940, Acc = 0.6250
# Training batch 503/2000
# Loss = 1.9358, Acc = 0.5000
# Training batch 504/2000
# Loss = 2.1784, Acc = 0.2500
# Training batch 505/2000
# Loss = 1.6839, Acc = 0.6250
# Training batch 506/2000
# Loss = 1.6176, Acc = 0.6250
# Training batch 507/2000
# Loss = 1.6189, Acc = 1.0000
# Training batch 508/2000
# Loss = 1.9072, Acc = 0.3750
# Training batch 509/2000
# Loss = 1.7626, Acc = 0.5000
# Training batch 510/2000
# Loss = 2.0566, Acc = 0.2500
# Training batch 511/2000
# Loss = 1.3934, Acc = 0.8750
# Training batch 512/2000
# Loss = 1.7067, Acc = 0.8750
# Training batch 513/2000
# Loss = 2.2045, Acc = 0.2500
# Training batch 514/2000
# Loss = 1.8741, Acc = 0.5000
# Training batch 515/2000
# Loss = 1.8408, Acc = 0.5000
# Training batch 516/2000
# Loss = 1.9193, Acc = 0.3750
# Training batch 517/2000
# Loss = 1.9356, Acc = 0.5000
# Training batch 518/2000
# Loss = 1.6964, Acc = 0.7500
# Training batch 519/2000
# Loss = 1.7956, Acc = 0.6250
# Training batch 520/2000
# Loss = 1.7825, Acc = 0.8750
# Training batch 521/2000
# Loss = 1.9952, Acc = 0.5000
# Training batch 522/2000
# Loss = 1.8625, Acc = 0.5000
# Training batch 523/2000
# Loss = 2.2931, Acc = 0.1250
# Training batch 524/2000
# Loss = 1.8632, Acc = 0.6250
# Training batch 525/2000
# Loss = 1.6912, Acc = 0.7500
# Training batch 526/2000
# Loss = 1.9499, Acc = 0.2500
# Training batch 527/2000
# Loss = 1.5966, Acc = 0.8750
# Training batch 528/2000
# Loss = 2.0148, Acc = 0.5000
# Training batch 529/2000
# Loss = 1.8396, Acc = 0.5000
# Training batch 530/2000
# Loss = 1.8643, Acc = 0.3750
# Training batch 531/2000
# Loss = 2.3182, Acc = 0.2500
# Training batch 532/2000
# Loss = 1.9984, Acc = 0.3750
# Training batch 533/2000
# Loss = 1.7888, Acc = 0.6250
# Training batch 534/2000
# Loss = 1.7261, Acc = 0.5000
# Training batch 535/2000
# Loss = 1.7443, Acc = 0.3750
# Training batch 536/2000
# Loss = 1.7163, Acc = 0.5000
# Training batch 537/2000
# Loss = 1.5893, Acc = 0.6250
# Training batch 538/2000
# Loss = 1.6753, Acc = 0.6250
# Training batch 539/2000
# Loss = 1.8593, Acc = 0.6250
# Training batch 540/2000
# Loss = 1.8638, Acc = 0.6250
# Training batch 541/2000
# Loss = 1.8747, Acc = 0.5000
# Training batch 542/2000
# Loss = 1.8684, Acc = 0.5000
# Training batch 543/2000
# Loss = 1.9547, Acc = 0.6250
# Training batch 544/2000
# Loss = 1.9762, Acc = 0.3750
# Training batch 545/2000
# Loss = 2.0978, Acc = 0.2500
# Training batch 546/2000
# Loss = 1.6923, Acc = 0.3750
# Training batch 547/2000
# Loss = 1.6286, Acc = 0.6250
# Training batch 548/2000
# Loss = 1.8070, Acc = 0.5000
# Training batch 549/2000
# Loss = 1.9609, Acc = 0.2500
# Training batch 550/2000
# Loss = 1.9505, Acc = 0.3750
# Training batch 551/2000
# Loss = 1.6519, Acc = 0.5000
# Training batch 552/2000
# Loss = 1.9174, Acc = 0.3750
# Training batch 553/2000
# Loss = 1.6538, Acc = 0.6250
# Training batch 554/2000
# Loss = 2.0618, Acc = 0.5000
# Training batch 555/2000
# Loss = 1.5795, Acc = 0.6250
# Training batch 556/2000
# Loss = 1.8679, Acc = 0.5000
# Training batch 557/2000
# Loss = 1.6664, Acc = 0.6250
# Training batch 558/2000
# Loss = 2.3634, Acc = 0.2500
# Training batch 559/2000
# Loss = 1.6964, Acc = 0.5000
# Training batch 560/2000
# Loss = 1.5774, Acc = 0.7500
# Training batch 561/2000
# Loss = 2.1133, Acc = 0.2500
# Training batch 562/2000
# Loss = 2.2617, Acc = 0.3750
# Training batch 563/2000
# Loss = 1.5532, Acc = 0.7500
# Training batch 564/2000
# Loss = 2.4966, Acc = 0.1250
# Training batch 565/2000
# Loss = 1.9410, Acc = 0.6250
# Training batch 566/2000
# Loss = 1.6695, Acc = 0.6250
# Training batch 567/2000
# Loss = 1.6280, Acc = 0.7500
# Training batch 568/2000
# Loss = 2.0290, Acc = 0.2500
# Training batch 569/2000
# Loss = 1.4334, Acc = 0.6250
# Training batch 570/2000
# Loss = 1.7748, Acc = 0.5000
# Training batch 571/2000
# Loss = 1.6010, Acc = 0.5000
# Training batch 572/2000
# Loss = 1.9001, Acc = 0.3750
# Training batch 573/2000
# Loss = 1.6018, Acc = 0.6250
# Training batch 574/2000
# Loss = 2.2191, Acc = 0.0000
# Training batch 575/2000
# Loss = 1.5033, Acc = 0.6250
# Training batch 576/2000
# Loss = 2.1512, Acc = 0.2500
# Training batch 577/2000
# Loss = 1.9455, Acc = 0.6250
# Training batch 578/2000
# Loss = 2.0460, Acc = 0.3750
# Training batch 579/2000
# Loss = 2.0071, Acc = 0.3750
# Training batch 580/2000
# Loss = 1.9693, Acc = 0.5000
# Training batch 581/2000
# Loss = 1.7002, Acc = 0.6250
# Training batch 582/2000
# Loss = 1.3707, Acc = 0.8750
# Training batch 583/2000
# Loss = 1.8253, Acc = 0.5000
# Training batch 584/2000
# Loss = 2.1348, Acc = 0.5000
# Training batch 585/2000
# Loss = 1.7817, Acc = 0.3750
# Training batch 586/2000
# Loss = 2.2552, Acc = 0.3750
# Training batch 587/2000
# Loss = 1.7789, Acc = 0.5000
# Training batch 588/2000
# Loss = 2.0395, Acc = 0.5000
# Training batch 589/2000
# Loss = 2.1112, Acc = 0.2500
# Training batch 590/2000
# Loss = 1.7132, Acc = 0.6250
# Training batch 591/2000
# Loss = 1.7862, Acc = 0.6250
# Training batch 592/2000
# Loss = 1.6722, Acc = 0.3750
# Training batch 593/2000
# Loss = 2.0553, Acc = 0.3750
# Training batch 594/2000
# Loss = 1.3796, Acc = 0.7500
# Training batch 595/2000
# Loss = 1.6013, Acc = 0.6250
# Training batch 596/2000
# Loss = 1.8339, Acc = 0.5000
# Training batch 597/2000
# Loss = 1.6456, Acc = 0.7500
# Training batch 598/2000
# Loss = 1.5088, Acc = 0.5000
# Training batch 599/2000
# Loss = 2.0575, Acc = 0.2500
# Training batch 600/2000
# Loss = 1.5951, Acc = 0.6250
# Training batch 601/2000
# Loss = 2.1381, Acc = 0.2500
# Training batch 602/2000
# Loss = 1.7030, Acc = 0.7500
# Training batch 603/2000
# Loss = 1.7785, Acc = 0.6250
# Training batch 604/2000
# Loss = 1.4735, Acc = 0.7500
# Training batch 605/2000
# Loss = 1.9236, Acc = 0.5000
# Training batch 606/2000
# Loss = 1.7122, Acc = 0.6250
# Training batch 607/2000
# Loss = 1.7596, Acc = 0.6250
# Training batch 608/2000
# Loss = 1.5055, Acc = 0.6250
# Training batch 609/2000
# Loss = 1.8839, Acc = 0.3750
# Training batch 610/2000
# Loss = 2.1297, Acc = 0.1250
# Training batch 611/2000
# Loss = 2.0280, Acc = 0.3750
# Training batch 612/2000
# Loss = 1.7991, Acc = 0.6250
# Training batch 613/2000
# Loss = 1.9695, Acc = 0.5000
# Training batch 614/2000
# Loss = 1.6688, Acc = 0.7500
# Training batch 615/2000
# Loss = 1.8534, Acc = 0.5000
# Training batch 616/2000
# Loss = 1.8557, Acc = 0.5000
# Training batch 617/2000
# Loss = 1.5186, Acc = 0.6250
# Training batch 618/2000
# Loss = 2.0155, Acc = 0.2500
# Training batch 619/2000
# Loss = 1.8564, Acc = 0.5000
# Training batch 620/2000
# Loss = 1.7073, Acc = 0.5000
# Training batch 621/2000
# Loss = 1.4039, Acc = 1.0000
# Training batch 622/2000
# Loss = 1.7231, Acc = 0.5000
# Training batch 623/2000
# Loss = 1.7270, Acc = 0.7500
# Training batch 624/2000
# Loss = 1.7264, Acc = 0.5000
# Training batch 625/2000
# Loss = 1.5943, Acc = 0.7500
# Training batch 626/2000
# Loss = 1.8486, Acc = 0.6250
# Training batch 627/2000
# Loss = 1.9468, Acc = 0.5000
# Training batch 628/2000
# Loss = 1.9554, Acc = 0.6250
# Training batch 629/2000
# Loss = 2.1084, Acc = 0.1250
# Training batch 630/2000
# Loss = 2.1244, Acc = 0.2500
# Training batch 631/2000
# Loss = 1.5581, Acc = 0.5000
# Training batch 632/2000
# Loss = 1.7379, Acc = 0.7500
# Training batch 633/2000
# Loss = 1.7940, Acc = 0.6250
# Training batch 634/2000
# Loss = 1.9499, Acc = 0.6250
# Training batch 635/2000
# Loss = 1.4122, Acc = 0.8750
# Training batch 636/2000
# Loss = 1.7020, Acc = 0.5000
# Training batch 637/2000
# Loss = 1.7561, Acc = 0.6250
# Training batch 638/2000
# Loss = 1.8948, Acc = 0.2500
# Training batch 639/2000
# Loss = 1.7048, Acc = 0.6250
# Training batch 640/2000
# Loss = 1.7936, Acc = 0.3750
# Training batch 641/2000
# Loss = 2.0110, Acc = 0.3750
# Training batch 642/2000
# Loss = 1.7359, Acc = 0.6250
# Training batch 643/2000
# Loss = 1.7664, Acc = 0.2500
# Training batch 644/2000
# Loss = 1.7186, Acc = 0.3750
# Training batch 645/2000
# Loss = 1.6618, Acc = 0.5000
# Training batch 646/2000
# Loss = 1.6191, Acc = 0.5000
# Training batch 647/2000
# Loss = 1.6750, Acc = 0.6250
# Training batch 648/2000
# Loss = 1.8569, Acc = 0.3750
# Training batch 649/2000
# Loss = 1.9348, Acc = 0.3750
# Training batch 650/2000
# Loss = 2.1826, Acc = 0.3750
# Training batch 651/2000
# Loss = 1.4820, Acc = 0.7500
# Training batch 652/2000
# Loss = 1.7142, Acc = 0.7500
# Training batch 653/2000
# Loss = 1.5149, Acc = 0.7500
# Training batch 654/2000
# Loss = 1.6455, Acc = 0.7500
# Training batch 655/2000
# Loss = 1.4917, Acc = 0.7500
# Training batch 656/2000
# Loss = 1.7089, Acc = 0.7500
# Training batch 657/2000
# Loss = 1.6881, Acc = 0.6250
# Training batch 658/2000
# Loss = 1.4715, Acc = 0.8750
# Training batch 659/2000
# Loss = 1.8964, Acc = 0.3750
# Training batch 660/2000
# Loss = 1.8341, Acc = 0.2500
# Training batch 661/2000
# Loss = 1.7030, Acc = 0.3750
# Training batch 662/2000
# Loss = 1.3410, Acc = 0.8750
# Training batch 663/2000
# Loss = 1.9131, Acc = 0.3750
# Training batch 664/2000
# Loss = 1.6844, Acc = 0.6250
# Training batch 665/2000
# Loss = 1.7886, Acc = 0.5000
# Training batch 666/2000
# Loss = 2.3303, Acc = 0.1250
# Training batch 667/2000
# Loss = 1.4046, Acc = 0.7500
# Training batch 668/2000
# Loss = 1.8952, Acc = 0.2500
# Training batch 669/2000
# Loss = 1.9913, Acc = 0.3750
# Training batch 670/2000
# Loss = 1.3173, Acc = 0.7500
# Training batch 671/2000
# Loss = 1.5684, Acc = 0.8750
# Training batch 672/2000
# Loss = 2.3148, Acc = 0.2500
# Training batch 673/2000
# Loss = 1.7469, Acc = 0.3750
# Training batch 674/2000
# Loss = 1.5769, Acc = 0.6250
# Training batch 675/2000
# Loss = 1.4426, Acc = 0.8750
# Training batch 676/2000
# Loss = 1.4886, Acc = 0.7500
# Training batch 677/2000
# Loss = 1.7893, Acc = 0.5000
# Training batch 678/2000
# Loss = 1.3285, Acc = 0.6250
# Training batch 679/2000
# Loss = 1.6498, Acc = 0.5000
# Training batch 680/2000
# Loss = 1.6722, Acc = 0.5000
# Training batch 681/2000
# Loss = 1.9729, Acc = 0.2500
# Training batch 682/2000
# Loss = 1.5546, Acc = 0.7500
# Training batch 683/2000
# Loss = 1.8544, Acc = 0.3750
# Training batch 684/2000
# Loss = 1.6821, Acc = 0.7500
# Training batch 685/2000
# Loss = 1.4864, Acc = 0.8750
# Training batch 686/2000
# Loss = 1.6698, Acc = 0.5000
# Training batch 687/2000
# Loss = 1.6735, Acc = 0.3750
# Training batch 688/2000
# Loss = 1.4787, Acc = 0.5000
# Training batch 689/2000
# Loss = 1.5051, Acc = 0.5000
# Training batch 690/2000
# Loss = 1.5417, Acc = 0.6250
# Training batch 691/2000
# Loss = 1.3214, Acc = 0.8750
# Training batch 692/2000
# Loss = 1.7699, Acc = 0.5000
# Training batch 693/2000
# Loss = 1.4818, Acc = 0.6250
# Training batch 694/2000
# Loss = 2.1287, Acc = 0.3750
# Training batch 695/2000
# Loss = 1.4927, Acc = 0.6250
# Training batch 696/2000
# Loss = 1.7055, Acc = 0.5000
# Training batch 697/2000
# Loss = 1.8465, Acc = 0.5000
# Training batch 698/2000
# Loss = 1.9111, Acc = 0.3750
# Training batch 699/2000
# Loss = 1.8341, Acc = 0.6250
# Training batch 700/2000
# Loss = 1.5379, Acc = 0.6250
# Training batch 701/2000
# Loss = 1.4827, Acc = 0.7500
# Training batch 702/2000
# Loss = 1.5094, Acc = 0.8750
# Training batch 703/2000
# Loss = 1.8432, Acc = 0.5000
# Training batch 704/2000
# Loss = 1.5392, Acc = 0.6250
# Training batch 705/2000
# Loss = 1.7612, Acc = 0.6250
# Training batch 706/2000
# Loss = 2.1295, Acc = 0.3750
# Training batch 707/2000
# Loss = 1.5162, Acc = 0.6250
# Training batch 708/2000
# Loss = 1.6457, Acc = 0.5000
# Training batch 709/2000
# Loss = 1.7180, Acc = 0.5000
# Training batch 710/2000
# Loss = 1.7724, Acc = 0.3750
# Training batch 711/2000
# Loss = 1.5784, Acc = 0.7500
# Training batch 712/2000
# Loss = 2.3074, Acc = 0.1250
# Training batch 713/2000
# Loss = 1.6115, Acc = 0.6250
# Training batch 714/2000
# Loss = 1.6578, Acc = 0.6250
# Training batch 715/2000
# Loss = 1.5985, Acc = 0.3750
# Training batch 716/2000
# Loss = 1.8303, Acc = 0.5000
# Training batch 717/2000
# Loss = 1.8694, Acc = 0.2500
# Training batch 718/2000
# Loss = 1.6248, Acc = 0.6250
# Training batch 719/2000
# Loss = 1.4617, Acc = 0.6250
# Training batch 720/2000
# Loss = 1.9671, Acc = 0.3750
# Training batch 721/2000
# Loss = 1.9108, Acc = 0.3750
# Training batch 722/2000
# Loss = 1.2499, Acc = 0.7500
# Training batch 723/2000
# Loss = 1.9397, Acc = 0.3750
# Training batch 724/2000
# Loss = 1.8779, Acc = 0.3750
# Training batch 725/2000
# Loss = 1.6636, Acc = 0.3750
# Training batch 726/2000
# Loss = 1.1935, Acc = 0.7500
# Training batch 727/2000
# Loss = 1.6392, Acc = 0.6250
# Training batch 728/2000
# Loss = 1.7065, Acc = 0.5000
# Training batch 729/2000
# Loss = 1.6374, Acc = 0.7500
# Training batch 730/2000
# Loss = 1.3318, Acc = 0.7500
# Training batch 731/2000
# Loss = 1.7845, Acc = 0.5000
# Training batch 732/2000
# Loss = 1.3972, Acc = 0.7500
# Training batch 733/2000
# Loss = 1.6796, Acc = 0.3750
# Training batch 734/2000
# Loss = 1.7246, Acc = 0.5000
# Training batch 735/2000
# Loss = 1.8841, Acc = 0.3750
# Training batch 736/2000
# Loss = 1.8332, Acc = 0.5000
# Training batch 737/2000
# Loss = 1.7364, Acc = 0.5000
# Training batch 738/2000
# Loss = 1.7371, Acc = 0.5000
# Training batch 739/2000
# Loss = 1.4767, Acc = 0.6250
# Training batch 740/2000
# Loss = 1.6852, Acc = 0.3750
# Training batch 741/2000
# Loss = 1.7346, Acc = 0.6250
# Training batch 742/2000
# Loss = 1.5390, Acc = 0.6250
# Training batch 743/2000
# Loss = 1.4312, Acc = 0.6250
# Training batch 744/2000
# Loss = 1.4088, Acc = 0.7500
# Training batch 745/2000
# Loss = 1.5834, Acc = 0.7500
# Training batch 746/2000
# Loss = 1.7340, Acc = 0.5000
# Training batch 747/2000
# Loss = 1.6951, Acc = 0.6250
# Training batch 748/2000
# Loss = 1.5754, Acc = 0.5000
# Training batch 749/2000
# Loss = 2.0345, Acc = 0.6250
# Training batch 750/2000
# Loss = 1.9409, Acc = 0.2500
# Training batch 751/2000
# Loss = 2.0379, Acc = 0.3750
# Training batch 752/2000
# Loss = 2.1703, Acc = 0.3750
# Training batch 753/2000
# Loss = 1.5965, Acc = 0.3750
# Training batch 754/2000
# Loss = 1.9716, Acc = 0.3750
# Training batch 755/2000
# Loss = 1.9967, Acc = 0.2500
# Training batch 756/2000
# Loss = 1.7855, Acc = 0.2500
# Training batch 757/2000
# Loss = 1.6246, Acc = 0.5000
# Training batch 758/2000
# Loss = 1.7132, Acc = 0.5000
# Training batch 759/2000
# Loss = 1.8371, Acc = 0.3750
# Training batch 760/2000
# Loss = 1.9357, Acc = 0.3750
# Training batch 761/2000
# Loss = 1.6023, Acc = 0.5000
# Training batch 762/2000
# Loss = 1.5574, Acc = 0.6250
# Training batch 763/2000
# Loss = 2.0328, Acc = 0.3750
# Training batch 764/2000
# Loss = 1.7241, Acc = 0.5000
# Training batch 765/2000
# Loss = 2.2579, Acc = 0.2500
# Training batch 766/2000
# Loss = 1.6150, Acc = 0.6250
# Training batch 767/2000
# Loss = 1.5476, Acc = 0.6250
# Training batch 768/2000
# Loss = 1.8822, Acc = 0.1250
# Training batch 769/2000
# Loss = 1.8584, Acc = 0.3750
# Training batch 770/2000
# Loss = 2.0711, Acc = 0.3750
# Training batch 771/2000
# Loss = 1.5650, Acc = 0.6250
# Training batch 772/2000
# Loss = 1.7465, Acc = 0.3750
# Training batch 773/2000
# Loss = 1.7485, Acc = 0.6250
# Training batch 774/2000
# Loss = 1.6149, Acc = 0.6250
# Training batch 775/2000
# Loss = 1.5703, Acc = 0.5000
# Training batch 776/2000
# Loss = 1.6868, Acc = 0.5000
# Training batch 777/2000
# Loss = 1.8081, Acc = 0.3750
# Training batch 778/2000
# Loss = 1.3470, Acc = 0.7500
# Training batch 779/2000
# Loss = 1.5582, Acc = 0.7500
# Training batch 780/2000
# Loss = 1.8785, Acc = 0.5000
# Training batch 781/2000
# Loss = 1.3183, Acc = 0.7500
# Training batch 782/2000
# Loss = 1.3763, Acc = 0.7500
# Training batch 783/2000
# Loss = 1.8410, Acc = 0.2500
# Training batch 784/2000
# Loss = 1.3197, Acc = 0.6250
# Training batch 785/2000
# Loss = 1.9354, Acc = 0.3750
# Training batch 786/2000
# Loss = 1.5380, Acc = 0.7500
# Training batch 787/2000
# Loss = 1.6464, Acc = 0.7500
# Training batch 788/2000
# Loss = 2.2314, Acc = 0.3750
# Training batch 789/2000
# Loss = 1.5264, Acc = 0.7500
# Training batch 790/2000
# Loss = 1.6095, Acc = 0.6250
# Training batch 791/2000
# Loss = 1.8941, Acc = 0.5000
# Training batch 792/2000
# Loss = 1.2648, Acc = 0.6250
# Training batch 793/2000
# Loss = 1.8827, Acc = 0.5000
# Training batch 794/2000
# Loss = 1.6946, Acc = 0.6250
# Training batch 795/2000
# Loss = 1.6778, Acc = 0.5000
# Training batch 796/2000
# Loss = 1.7123, Acc = 0.5000
# Training batch 797/2000
# Loss = 1.5316, Acc = 0.6250
# Training batch 798/2000
# Loss = 1.2978, Acc = 0.6250
# Training batch 799/2000
# Loss = 1.4665, Acc = 0.6250
# Training batch 800/2000
# Loss = 1.4235, Acc = 0.6250
# Training batch 801/2000
# Loss = 1.8835, Acc = 0.5000
# Training batch 802/2000
# Loss = 1.5589, Acc = 0.5000
# Training batch 803/2000
# Loss = 2.2734, Acc = 0.1250
# Training batch 804/2000
# Loss = 1.6197, Acc = 0.5000
# Training batch 805/2000
# Loss = 1.7231, Acc = 0.6250
# Training batch 806/2000
# Loss = 1.3911, Acc = 0.7500
# Training batch 807/2000
# Loss = 1.4799, Acc = 0.5000
# Training batch 808/2000
# Loss = 1.8377, Acc = 0.3750
# Training batch 809/2000
# Loss = 1.4545, Acc = 0.6250
# Training batch 810/2000
# Loss = 1.3965, Acc = 0.5000
# Training batch 811/2000
# Loss = 1.6223, Acc = 0.5000
# Training batch 812/2000
# Loss = 1.6756, Acc = 0.6250
# Training batch 813/2000
# Loss = 1.8795, Acc = 0.3750
# Training batch 814/2000
# Loss = 1.5073, Acc = 0.5000
# Training batch 815/2000
# Loss = 1.7698, Acc = 0.3750
# Training batch 816/2000
# Loss = 1.8719, Acc = 0.5000
# Training batch 817/2000
# Loss = 1.3203, Acc = 0.7500
# Training batch 818/2000
# Loss = 2.0990, Acc = 0.2500
# Training batch 819/2000
# Loss = 1.5193, Acc = 0.5000
# Training batch 820/2000
# Loss = 1.4068, Acc = 0.6250
# Training batch 821/2000
# Loss = 1.4355, Acc = 0.7500
# Training batch 822/2000
# Loss = 1.6505, Acc = 0.6250
# Training batch 823/2000
# Loss = 2.0784, Acc = 0.2500
# Training batch 824/2000
# Loss = 1.4490, Acc = 0.7500
# Training batch 825/2000
# Loss = 1.7181, Acc = 0.5000
# Training batch 826/2000
# Loss = 2.0317, Acc = 0.2500
# Training batch 827/2000
# Loss = 1.7084, Acc = 0.5000
# Training batch 828/2000
# Loss = 1.4134, Acc = 0.6250
# Training batch 829/2000
# Loss = 1.9175, Acc = 0.2500
# Training batch 830/2000
# Loss = 1.4944, Acc = 0.5000
# Training batch 831/2000
# Loss = 1.3003, Acc = 0.7500
# Training batch 832/2000
# Loss = 1.7532, Acc = 0.5000
# Training batch 833/2000
# Loss = 1.6647, Acc = 0.6250
# Training batch 834/2000
# Loss = 2.1721, Acc = 0.3750
# Training batch 835/2000
# Loss = 1.7460, Acc = 0.2500
# Training batch 836/2000
# Loss = 1.2471, Acc = 0.7500
# Training batch 837/2000
# Loss = 1.2337, Acc = 0.7500
# Training batch 838/2000
# Loss = 1.6809, Acc = 0.3750
# Training batch 839/2000
# Loss = 1.9742, Acc = 0.3750
# Training batch 840/2000
# Loss = 1.7979, Acc = 0.3750
# Training batch 841/2000
# Loss = 1.1386, Acc = 1.0000
# Training batch 842/2000
# Loss = 1.1154, Acc = 0.6250
# Training batch 843/2000
# Loss = 2.3420, Acc = 0.3750
# Training batch 844/2000
# Loss = 1.4813, Acc = 0.6250
# Training batch 845/2000
# Loss = 1.2920, Acc = 0.7500
# Training batch 846/2000
# Loss = 1.6733, Acc = 0.5000
# Training batch 847/2000
# Loss = 1.9513, Acc = 0.3750
# Training batch 848/2000
# Loss = 1.4133, Acc = 0.3750
# Training batch 849/2000
# Loss = 1.6221, Acc = 0.3750
# Training batch 850/2000
# Loss = 1.7484, Acc = 0.3750
# Training batch 851/2000
# Loss = 2.0112, Acc = 0.3750
# Training batch 852/2000
# Loss = 2.1565, Acc = 0.3750
# Training batch 853/2000
# Loss = 1.2365, Acc = 0.7500
# Training batch 854/2000
# Loss = 1.3603, Acc = 0.5000
# Training batch 855/2000
# Loss = 1.7056, Acc = 0.5000
# Training batch 856/2000
# Loss = 2.2693, Acc = 0.5000
# Training batch 857/2000
# Loss = 1.8294, Acc = 0.3750
# Training batch 858/2000
# Loss = 1.5953, Acc = 0.6250
# Training batch 859/2000
# Loss = 1.6938, Acc = 0.3750
# Training batch 860/2000
# Loss = 1.9856, Acc = 0.3750
# Training batch 861/2000
# Loss = 1.4932, Acc = 0.6250
# Training batch 862/2000
# Loss = 1.2877, Acc = 0.6250
# Training batch 863/2000
# Loss = 1.6467, Acc = 0.5000
# Training batch 864/2000
# Loss = 1.6579, Acc = 0.6250
# Training batch 865/2000
# Loss = 1.4974, Acc = 0.7500
# Training batch 866/2000
# Loss = 1.7925, Acc = 0.5000
# Training batch 867/2000
# Loss = 1.5570, Acc = 0.5000
# Training batch 868/2000
# Loss = 1.9088, Acc = 0.3750
# Training batch 869/2000
# Loss = 1.6805, Acc = 0.6250
# Training batch 870/2000
# Loss = 2.1060, Acc = 0.5000
# Training batch 871/2000
# Loss = 1.4756, Acc = 0.6250
# Training batch 872/2000
# Loss = 1.7712, Acc = 0.3750
# Training batch 873/2000
# Loss = 1.7180, Acc = 0.5000
# Training batch 874/2000
# Loss = 1.7761, Acc = 0.5000
# Training batch 875/2000
# Loss = 1.6021, Acc = 0.5000
# Training batch 876/2000
# Loss = 1.7551, Acc = 0.5000
# Training batch 877/2000
# Loss = 1.5201, Acc = 0.5000
# Training batch 878/2000
# Loss = 1.7838, Acc = 0.5000
# Training batch 879/2000
# Loss = 1.1817, Acc = 0.8750
# Training batch 880/2000
# Loss = 1.9116, Acc = 0.3750
# Training batch 881/2000
# Loss = 1.1652, Acc = 0.6250
# Training batch 882/2000
# Loss = 1.7059, Acc = 0.5000
# Training batch 883/2000
# Loss = 2.2271, Acc = 0.2500
# Training batch 884/2000
# Loss = 1.1945, Acc = 0.7500
# Training batch 885/2000
# Loss = 2.0237, Acc = 0.2500
# Training batch 886/2000
# Loss = 1.6218, Acc = 0.3750
# Training batch 887/2000
# Loss = 1.5793, Acc = 0.6250
# Training batch 888/2000
# Loss = 1.7551, Acc = 0.6250
# Training batch 889/2000
# Loss = 1.3885, Acc = 0.6250
# Training batch 890/2000
# Loss = 1.6377, Acc = 0.5000
# Training batch 891/2000
# Loss = 1.9171, Acc = 0.5000
# Training batch 892/2000
# Loss = 1.8354, Acc = 0.5000
# Training batch 893/2000
# Loss = 1.8024, Acc = 0.2500
# Training batch 894/2000
# Loss = 1.5325, Acc = 0.6250
# Training batch 895/2000
# Loss = 1.9140, Acc = 0.6250
# Training batch 896/2000
# Loss = 1.3860, Acc = 0.7500
# Training batch 897/2000
# Loss = 1.1770, Acc = 1.0000
# Training batch 898/2000
# Loss = 1.3512, Acc = 0.7500
# Training batch 899/2000
# Loss = 1.4093, Acc = 0.6250
# Training batch 900/2000
# Loss = 1.4047, Acc = 0.7500
# Training batch 901/2000
# Loss = 1.4983, Acc = 0.5000
# Training batch 902/2000
# Loss = 1.6448, Acc = 0.6250
# Training batch 903/2000
# Loss = 1.3953, Acc = 0.7500
# Training batch 904/2000
# Loss = 1.6141, Acc = 0.5000
# Training batch 905/2000
# Loss = 1.8135, Acc = 0.6250
# Training batch 906/2000
# Loss = 2.1109, Acc = 0.3750
# Training batch 907/2000
# Loss = 1.6899, Acc = 0.3750
# Training batch 908/2000
# Loss = 1.4820, Acc = 0.5000
# Training batch 909/2000
# Loss = 1.4670, Acc = 0.7500
# Training batch 910/2000
# Loss = 1.5081, Acc = 0.6250
# Training batch 911/2000
# Loss = 1.5243, Acc = 0.5000
# Training batch 912/2000
# Loss = 1.5466, Acc = 0.5000
# Training batch 913/2000
# Loss = 1.4389, Acc = 0.6250
# Training batch 914/2000
# Loss = 1.3731, Acc = 0.6250
# Training batch 915/2000
# Loss = 1.6026, Acc = 0.3750
# Training batch 916/2000
# Loss = 1.7080, Acc = 0.3750
# Training batch 917/2000
# Loss = 1.4704, Acc = 0.6250
# Training batch 918/2000
# Loss = 2.1110, Acc = 0.3750
# Training batch 919/2000
# Loss = 1.6991, Acc = 0.5000
# Training batch 920/2000
# Loss = 1.1567, Acc = 0.7500
# Training batch 921/2000
# Loss = 1.5964, Acc = 0.6250
# Training batch 922/2000
# Loss = 1.4442, Acc = 0.7500
# Training batch 923/2000
# Loss = 1.4192, Acc = 0.6250
# Training batch 924/2000
# Loss = 1.3512, Acc = 0.6250
# Training batch 925/2000
# ...
# Training batch 1700/2000
# Loss = 1.3930, Acc = 0.6250
# Training batch 1701/2000
# Loss = 0.4709, Acc = 0.8750
# Training batch 1702/2000
# Loss = 0.6130, Acc = 0.8750
# Training batch 1703/2000
# Loss = 1.1803, Acc = 0.6250
# Training batch 1704/2000
# Loss = 0.5539, Acc = 0.8750
# Training batch 1705/2000
# Loss = 0.3372, Acc = 0.8750
# Training batch 1706/2000
# Loss = 0.5022, Acc = 0.7500
# Training batch 1707/2000
# Loss = 0.1752, Acc = 1.0000
# Training batch 1708/2000
# Loss = 0.3043, Acc = 0.8750
# Training batch 1709/2000
# Loss = 1.0108, Acc = 0.6250
# Training batch 1710/2000
# Loss = 0.2504, Acc = 1.0000
# Training batch 1711/2000
# Loss = 0.0500, Acc = 1.0000
# Training batch 1712/2000
# Loss = 0.5494, Acc = 0.8750
# Training batch 1713/2000
# Loss = 0.1977, Acc = 0.8750
# Training batch 1714/2000
# Loss = 0.9572, Acc = 0.7500
# Training batch 1715/2000
# Loss = 0.7437, Acc = 0.7500
# Training batch 1716/2000
# Loss = 0.6226, Acc = 0.8750
# Training batch 1717/2000
# Loss = 0.1874, Acc = 1.0000
# Training batch 1718/2000
# Loss = 0.5420, Acc = 0.7500
# Training batch 1719/2000
# Loss = 0.5317, Acc = 0.7500
# Training batch 1720/2000
# Loss = 0.4906, Acc = 0.8750
# Training batch 1721/2000
# Loss = 0.5182, Acc = 0.8750
# Training batch 1722/2000
# Loss = 1.6743, Acc = 0.6250
# Training batch 1723/2000
# Loss = 0.6629, Acc = 0.7500
# Training batch 1724/2000
# Loss = 0.0776, Acc = 1.0000
# Training batch 1725/2000
# Loss = 0.2579, Acc = 0.8750
# Training batch 1726/2000
# Loss = 0.4206, Acc = 0.8750
# Training batch 1727/2000
# Loss = 0.1912, Acc = 1.0000
# Training batch 1728/2000
# Loss = 0.1295, Acc = 1.0000
# Training batch 1729/2000
# Loss = 1.6819, Acc = 0.3750
# Training batch 1730/2000
# Loss = 0.8144, Acc = 0.7500
# Training batch 1731/2000
# Loss = 0.5519, Acc = 0.7500
# Training batch 1732/2000
# Loss = 0.7525, Acc = 0.6250
# Training batch 1733/2000
# Loss = 0.4724, Acc = 0.8750
# Training batch 1734/2000
# Loss = 0.0931, Acc = 1.0000
# Training batch 1735/2000
# Loss = 0.2279, Acc = 1.0000
# Training batch 1736/2000
# Loss = 0.2532, Acc = 0.8750
# Training batch 1737/2000
# Loss = 0.3966, Acc = 0.8750
# Training batch 1738/2000
# Loss = 0.2844, Acc = 0.8750
# Training batch 1739/2000
# Loss = 0.6125, Acc = 0.8750
# Training batch 1740/2000
# Loss = 0.1104, Acc = 1.0000
# Training batch 1741/2000
# Loss = 0.2854, Acc = 1.0000
# Training batch 1742/2000
# Loss = 0.0591, Acc = 1.0000
# Training batch 1743/2000
# Loss = 0.4028, Acc = 0.8750
# Training batch 1744/2000
# Loss = 0.3050, Acc = 1.0000
# Training batch 1745/2000
# Loss = 1.0588, Acc = 0.6250
# Training batch 1746/2000
# Loss = 0.4934, Acc = 0.8750
# Training batch 1747/2000
# Loss = 0.6447, Acc = 0.8750
# Training batch 1748/2000
# Loss = 0.5949, Acc = 0.8750
# Training batch 1749/2000
# Loss = 0.1339, Acc = 1.0000
# Training batch 1750/2000
# Loss = 0.4456, Acc = 0.8750
# Training batch 1751/2000
# Loss = 0.6471, Acc = 0.8750
# Training batch 1752/2000
# Loss = 0.3904, Acc = 0.8750
# Training batch 1753/2000
# Loss = 0.5807, Acc = 0.8750
# Training batch 1754/2000
# Loss = 0.2575, Acc = 1.0000
# Training batch 1755/2000
# Loss = 0.1538, Acc = 1.0000
# Training batch 1756/2000
# Loss = 0.6272, Acc = 0.7500
# Training batch 1757/2000
# Loss = 0.3265, Acc = 1.0000
# Training batch 1758/2000
# Loss = 0.8517, Acc = 0.7500
# Training batch 1759/2000
# Loss = 0.2157, Acc = 0.8750
# Training batch 1760/2000
# Loss = 0.1131, Acc = 1.0000
# Training batch 1761/2000
# Loss = 0.7179, Acc = 0.7500
# Training batch 1762/2000
# Loss = 0.2107, Acc = 1.0000
# Training batch 1763/2000
# Loss = 0.2112, Acc = 1.0000
# Training batch 1764/2000
# Loss = 0.7501, Acc = 0.7500
# Training batch 1765/2000
# Loss = 0.5354, Acc = 0.7500
# Training batch 1766/2000
# Loss = 0.8533, Acc = 0.8750
# Training batch 1767/2000
# Loss = 0.1362, Acc = 1.0000
# Training batch 1768/2000
# Loss = 0.1308, Acc = 1.0000
# Training batch 1769/2000
# Loss = 0.3056, Acc = 0.8750
# Training batch 1770/2000
# Loss = 0.8887, Acc = 0.6250
# Training batch 1771/2000
# Loss = 0.4224, Acc = 0.8750
# Training batch 1772/2000
# Loss = 0.6142, Acc = 0.7500
# Training batch 1773/2000
# Loss = 0.4365, Acc = 0.7500
# Training batch 1774/2000
# Loss = 0.0781, Acc = 1.0000
# Training batch 1775/2000
# Loss = 0.3845, Acc = 0.8750
# Training batch 1776/2000
# Loss = 0.5200, Acc = 0.8750
# Training batch 1777/2000
# Loss = 0.1665, Acc = 1.0000
# Training batch 1778/2000
# Loss = 0.2961, Acc = 0.8750
# Training batch 1779/2000
# Loss = 0.8196, Acc = 0.6250
# Training batch 1780/2000
# Loss = 0.4478, Acc = 0.8750
# Training batch 1781/2000
# Loss = 0.2106, Acc = 1.0000
# Training batch 1782/2000
# Loss = 0.1085, Acc = 1.0000
# Training batch 1783/2000
# Loss = 0.7803, Acc = 0.6250
# Training batch 1784/2000
# Loss = 1.1338, Acc = 0.7500
# Training batch 1785/2000
# Loss = 0.2045, Acc = 1.0000
# Training batch 1786/2000
# Loss = 1.2352, Acc = 0.5000
# Training batch 1787/2000
# Loss = 0.6431, Acc = 0.7500
# Training batch 1788/2000
# Loss = 0.2102, Acc = 1.0000
# Training batch 1789/2000
# Loss = 0.4448, Acc = 0.7500
# Training batch 1790/2000
# Loss = 0.8399, Acc = 0.6250
# Training batch 1791/2000
# Loss = 0.5721, Acc = 0.7500
# Training batch 1792/2000
# Loss = 0.2290, Acc = 1.0000
# Training batch 1793/2000
# Loss = 0.7577, Acc = 0.7500
# Training batch 1794/2000
# Loss = 0.2652, Acc = 0.8750
# Training batch 1795/2000
# Loss = 0.8964, Acc = 0.6250
# Training batch 1796/2000
# Loss = 0.5127, Acc = 0.7500
# Training batch 1797/2000
# Loss = 0.4449, Acc = 0.8750
# Training batch 1798/2000
# Loss = 0.4517, Acc = 0.7500
# Training batch 1799/2000
# Loss = 0.4823, Acc = 0.8750
# Training batch 1800/2000
# Loss = 0.2645, Acc = 1.0000
# Training batch 1801/2000
# Loss = 0.4506, Acc = 0.7500
# Training batch 1802/2000
# Loss = 0.6429, Acc = 0.7500
# Training batch 1803/2000
# Loss = 0.8900, Acc = 0.5000
# Training batch 1804/2000
# Loss = 0.7541, Acc = 0.7500
# Training batch 1805/2000
# Loss = 0.0814, Acc = 1.0000
# Training batch 1806/2000
# Loss = 0.2122, Acc = 1.0000
# Training batch 1807/2000
# Loss = 0.3899, Acc = 0.8750
# Training batch 1808/2000
# Loss = 0.4836, Acc = 0.7500
# Training batch 1809/2000
# Loss = 0.5034, Acc = 0.7500
# Training batch 1810/2000
# Loss = 0.0739, Acc = 1.0000
# Training batch 1811/2000
# Loss = 0.4403, Acc = 0.8750
# Training batch 1812/2000
# Loss = 0.2194, Acc = 1.0000
# Training batch 1813/2000
# Loss = 0.6450, Acc = 0.6250
# Training batch 1814/2000
# Loss = 0.6321, Acc = 0.6250
# Training batch 1815/2000
# Loss = 0.5585, Acc = 0.7500
# Training batch 1816/2000
# Loss = 0.6617, Acc = 0.6250
# Training batch 1817/2000
# Loss = 0.3707, Acc = 0.8750
# Training batch 1818/2000
# Loss = 0.2058, Acc = 1.0000
# Training batch 1819/2000
# Loss = 0.3171, Acc = 0.8750
# Training batch 1820/2000
# Loss = 0.5893, Acc = 0.7500
# Training batch 1821/2000
# Loss = 1.0328, Acc = 0.7500
# Training batch 1822/2000
# Loss = 0.5571, Acc = 0.6250
# Training batch 1823/2000
# Loss = 0.2751, Acc = 1.0000
# Training batch 1824/2000
# Loss = 0.3434, Acc = 0.8750
# Training batch 1825/2000
# Loss = 0.6078, Acc = 0.8750
# Training batch 1826/2000
# Loss = 1.2273, Acc = 0.5000
# Training batch 1827/2000
# Loss = 0.6850, Acc = 0.6250
# Training batch 1828/2000
# Loss = 0.6268, Acc = 0.6250
# Training batch 1829/2000
# Loss = 0.6596, Acc = 0.7500
# Training batch 1830/2000
# Loss = 0.3114, Acc = 0.8750
# Training batch 1831/2000
# Loss = 0.4565, Acc = 0.7500
# Training batch 1832/2000
# Loss = 0.7378, Acc = 0.6250
# Training batch 1833/2000
# Loss = 0.2115, Acc = 1.0000
# Training batch 1834/2000
# Loss = 0.2711, Acc = 0.8750
# Training batch 1835/2000
# Loss = 0.1485, Acc = 1.0000
# Training batch 1836/2000
# Loss = 0.3742, Acc = 0.7500
# Training batch 1837/2000
# Loss = 0.0752, Acc = 1.0000
# Training batch 1838/2000
# Loss = 0.2314, Acc = 0.8750
# Training batch 1839/2000
# Loss = 0.3835, Acc = 0.8750
# Training batch 1840/2000
# Loss = 0.3366, Acc = 1.0000
# Training batch 1841/2000
# Loss = 0.4389, Acc = 0.8750
# Training batch 1842/2000
# Loss = 0.2187, Acc = 1.0000
# Training batch 1843/2000
# Loss = 0.6452, Acc = 0.8750
# Training batch 1844/2000
# Loss = 0.6110, Acc = 0.8750
# Training batch 1845/2000
# Loss = 1.1811, Acc = 0.6250
# Training batch 1846/2000
# Loss = 0.5040, Acc = 0.7500
# Training batch 1847/2000
# Loss = 1.0648, Acc = 0.6250
# Training batch 1848/2000
# Loss = 1.2830, Acc = 0.6250
# Training batch 1849/2000
# Loss = 0.4501, Acc = 0.8750
# Training batch 1850/2000
# Loss = 0.4460, Acc = 0.8750
# Training batch 1851/2000
# Loss = 0.3939, Acc = 0.8750
# Training batch 1852/2000
# Loss = 0.5065, Acc = 0.7500
# Training batch 1853/2000
# Loss = 0.5549, Acc = 0.7500
# Training batch 1854/2000
# Loss = 0.7676, Acc = 0.7500
# Training batch 1855/2000
# Loss = 0.7019, Acc = 0.6250
# Training batch 1856/2000
# Loss = 0.7788, Acc = 0.5000
# Training batch 1857/2000
# Loss = 0.8377, Acc = 0.7500
# Training batch 1858/2000
# Loss = 0.3170, Acc = 0.8750
# Training batch 1859/2000
# Loss = 0.3348, Acc = 0.8750
# Training batch 1860/2000
# Loss = 0.6189, Acc = 0.8750
# Training batch 1861/2000
# Loss = 0.7488, Acc = 0.6250
# Training batch 1862/2000
# Loss = 0.2098, Acc = 0.8750
# Training batch 1863/2000
# Loss = 0.7887, Acc = 0.7500
# Training batch 1864/2000
# Loss = 0.3612, Acc = 0.8750
# Training batch 1865/2000
# Loss = 0.1782, Acc = 1.0000
# Training batch 1866/2000
# Loss = 0.3991, Acc = 0.8750
# Training batch 1867/2000
# Loss = 0.5360, Acc = 0.8750
# Training batch 1868/2000
# Loss = 0.3932, Acc = 0.8750
# Training batch 1869/2000
# Loss = 0.3110, Acc = 0.8750
# Training batch 1870/2000
# Loss = 0.9869, Acc = 0.6250
# Training batch 1871/2000
# Loss = 0.2074, Acc = 1.0000
# Training batch 1872/2000
# Loss = 0.3255, Acc = 0.8750
# Training batch 1873/2000
# Loss = 0.5845, Acc = 0.8750
# Training batch 1874/2000
# Loss = 0.4021, Acc = 0.8750
# Training batch 1875/2000
# Loss = 0.4117, Acc = 0.7500
# Training batch 1876/2000
# Loss = 0.8045, Acc = 0.7500
# Training batch 1877/2000
# Loss = 1.0001, Acc = 0.7500
# Training batch 1878/2000
# Loss = 0.4451, Acc = 0.8750
# Training batch 1879/2000
# Loss = 0.1816, Acc = 1.0000
# Training batch 1880/2000
# Loss = 0.4286, Acc = 0.7500
# Training batch 1881/2000
# Loss = 1.1157, Acc = 0.6250
# Training batch 1882/2000
# Loss = 0.5355, Acc = 0.7500
# Training batch 1883/2000
# Loss = 0.4837, Acc = 0.7500
# Training batch 1884/2000
# Loss = 0.6691, Acc = 0.7500
# Training batch 1885/2000
# Loss = 0.6395, Acc = 0.6250
# Training batch 1886/2000
# Loss = 0.6889, Acc = 0.6250
# Training batch 1887/2000
# Loss = 0.4100, Acc = 0.7500
# Training batch 1888/2000
# Loss = 0.4314, Acc = 0.8750
# Training batch 1889/2000
# Loss = 1.0219, Acc = 0.5000
# Training batch 1890/2000
# Loss = 0.3333, Acc = 0.8750
# Training batch 1891/2000
# Loss = 0.7731, Acc = 0.6250
# Training batch 1892/2000
# Loss = 0.6102, Acc = 0.7500
# Training batch 1893/2000
# Loss = 0.8449, Acc = 0.6250
# Training batch 1894/2000
# Loss = 0.8089, Acc = 0.6250
# Training batch 1895/2000
# Loss = 0.3610, Acc = 0.8750
# Training batch 1896/2000
# Loss = 0.8883, Acc = 0.7500
# Training batch 1897/2000
# Loss = 0.4900, Acc = 0.8750
# Training batch 1898/2000
# Loss = 0.3674, Acc = 0.8750
# Training batch 1899/2000
# Loss = 0.2756, Acc = 0.8750
# Training batch 1900/2000
# Loss = 0.6539, Acc = 0.6250
# Training batch 1901/2000
# Loss = 0.6185, Acc = 0.7500
# Training batch 1902/2000
# Loss = 1.1280, Acc = 0.6250
# Training batch 1903/2000
# Loss = 0.5267, Acc = 0.8750
# Training batch 1904/2000
# Loss = 0.0645, Acc = 1.0000
# Training batch 1905/2000
# Loss = 0.2843, Acc = 0.8750
# Training batch 1906/2000
# Loss = 0.4963, Acc = 0.7500
# Training batch 1907/2000
# Loss = 0.0959, Acc = 1.0000
# Training batch 1908/2000
# Loss = 1.0136, Acc = 0.6250
# Training batch 1909/2000
# Loss = 0.6978, Acc = 0.8750
# Training batch 1910/2000
# Loss = 0.4812, Acc = 0.8750
# Training batch 1911/2000
# Loss = 0.2583, Acc = 1.0000
# Training batch 1912/2000
# Loss = 0.6720, Acc = 0.6250
# Training batch 1913/2000
# Loss = 0.7464, Acc = 0.8750
# Training batch 1914/2000
# Loss = 0.4116, Acc = 0.8750
# Training batch 1915/2000
# Loss = 0.1205, Acc = 1.0000
# Training batch 1916/2000
# Loss = 1.1706, Acc = 0.6250
# Training batch 1917/2000
# Loss = 1.0039, Acc = 0.7500
# Training batch 1918/2000
# Loss = 0.3286, Acc = 0.8750
# Training batch 1919/2000
# Loss = 0.2894, Acc = 1.0000
# Training batch 1920/2000
# Loss = 0.9796, Acc = 0.7500
# Training batch 1921/2000
# Loss = 1.0574, Acc = 0.5000
# Training batch 1922/2000
# Loss = 0.1323, Acc = 1.0000
# Training batch 1923/2000
# Loss = 0.3024, Acc = 1.0000
# Training batch 1924/2000
# Loss = 0.5762, Acc = 0.7500
# Training batch 1925/2000
# Loss = 0.2288, Acc = 1.0000
# Training batch 1926/2000
# Loss = 0.1071, Acc = 1.0000
# Training batch 1927/2000
# Loss = 0.9054, Acc = 0.6250
# Training batch 1928/2000
# Loss = 0.5711, Acc = 0.8750
# Training batch 1929/2000
# Loss = 0.5615, Acc = 0.7500
# Training batch 1930/2000
# Loss = 0.3053, Acc = 1.0000
# Training batch 1931/2000
# Loss = 0.5100, Acc = 0.8750
# Training batch 1932/2000
# Loss = 0.3998, Acc = 0.8750
# Training batch 1933/2000
# Loss = 0.5204, Acc = 0.7500
# Training batch 1934/2000
# Loss = 0.8694, Acc = 0.8750
# Training batch 1935/2000
# Loss = 0.2444, Acc = 0.8750
# Training batch 1936/2000
# Loss = 0.4787, Acc = 0.8750
# Training batch 1937/2000
# Loss = 0.2506, Acc = 1.0000
# Training batch 1938/2000
# Loss = 0.1608, Acc = 1.0000
# Training batch 1939/2000
# Loss = 0.1793, Acc = 1.0000
# Training batch 1940/2000
# Loss = 0.9417, Acc = 0.7500
# Training batch 1941/2000
# Loss = 0.2464, Acc = 1.0000
# Training batch 1942/2000
# Loss = 0.7950, Acc = 0.5000
# Training batch 1943/2000
# Loss = 0.3720, Acc = 1.0000
# Training batch 1944/2000
# Loss = 0.4000, Acc = 0.8750
# Training batch 1945/2000
# Loss = 0.3816, Acc = 0.8750
# Training batch 1946/2000
# Loss = 0.3357, Acc = 0.8750
# Training batch 1947/2000
# Loss = 0.5468, Acc = 0.8750
# Training batch 1948/2000
# Loss = 0.7304, Acc = 0.7500
# Training batch 1949/2000
# Loss = 0.3170, Acc = 0.8750
# Training batch 1950/2000
# Loss = 1.3717, Acc = 0.3750
# Training batch 1951/2000
# Loss = 1.2355, Acc = 0.5000
# Training batch 1952/2000
# Loss = 0.6062, Acc = 0.8750
# Training batch 1953/2000
# Loss = 0.0970, Acc = 1.0000
# Training batch 1954/2000
# Loss = 0.8416, Acc = 0.8750
# Training batch 1955/2000
# Loss = 0.4391, Acc = 0.8750
# Training batch 1956/2000
# Loss = 1.0202, Acc = 0.7500
# Training batch 1957/2000
# Loss = 0.7977, Acc = 0.6250
# Training batch 1958/2000
# Loss = 1.3265, Acc = 0.6250
# Training batch 1959/2000
# Loss = 0.7423, Acc = 0.6250
# Training batch 1960/2000
# Loss = 0.4004, Acc = 0.7500
# Training batch 1961/2000
# Loss = 0.1181, Acc = 1.0000
# Training batch 1962/2000
# Loss = 0.5538, Acc = 0.7500
# Training batch 1963/2000
# Loss = 0.1919, Acc = 1.0000
# Training batch 1964/2000
# Loss = 0.3813, Acc = 0.8750
# Training batch 1965/2000
# Loss = 0.5976, Acc = 0.8750
# Training batch 1966/2000
# Loss = 1.0146, Acc = 0.6250
# Training batch 1967/2000
# Loss = 0.7834, Acc = 0.6250
# Training batch 1968/2000
# Loss = 0.6065, Acc = 0.7500
# Training batch 1969/2000
# Loss = 0.3628, Acc = 0.8750
# Training batch 1970/2000
# Loss = 0.4436, Acc = 0.8750
# Training batch 1971/2000
# Loss = 0.3807, Acc = 0.8750
# Training batch 1972/2000
# Loss = 0.3960, Acc = 0.8750
# Training batch 1973/2000
# Loss = 0.7374, Acc = 0.7500
# Training batch 1974/2000
# Loss = 0.8919, Acc = 0.6250
# Training batch 1975/2000
# Loss = 0.7792, Acc = 0.8750
# Training batch 1976/2000
# Loss = 1.0778, Acc = 0.6250
# Training batch 1977/2000
# Loss = 0.1029, Acc = 1.0000
# Training batch 1978/2000
# Loss = 0.4232, Acc = 0.8750
# Training batch 1979/2000
# Loss = 0.3437, Acc = 0.8750
# Training batch 1980/2000
# Loss = 0.7314, Acc = 0.8750
# Training batch 1981/2000
# Loss = 0.4790, Acc = 0.7500
# Training batch 1982/2000
# Loss = 0.5744, Acc = 0.7500
# Training batch 1983/2000
# Loss = 0.2200, Acc = 1.0000
# Training batch 1984/2000
# Loss = 0.9303, Acc = 0.7500
# Training batch 1985/2000
# Loss = 0.6667, Acc = 0.7500
# Training batch 1986/2000
# Loss = 0.6729, Acc = 0.8750
# Training batch 1987/2000
# Loss = 1.3205, Acc = 0.6250
# Training batch 1988/2000
# Loss = 0.3445, Acc = 0.8750
# Training batch 1989/2000
# Loss = 0.7014, Acc = 0.7500
# Training batch 1990/2000
# Loss = 0.2404, Acc = 0.8750
# Training batch 1991/2000
# Loss = 0.4011, Acc = 0.8750
# Training batch 1992/2000
# Loss = 0.2334, Acc = 0.8750
# Training batch 1993/2000
# Loss = 0.1885, Acc = 1.0000
# Training batch 1994/2000
# Loss = 0.6337, Acc = 0.8750
# Training batch 1995/2000
# Loss = 0.5060, Acc = 0.7500
# Training batch 1996/2000
# Loss = 0.2490, Acc = 1.0000
# Training batch 1997/2000
# Loss = 0.5792, Acc = 0.7500
# Training batch 1998/2000
# Loss = 0.7038, Acc = 0.6250
# Training batch 1999/2000
# Loss = 0.1676, Acc = 1.0000
# Training batch 2000/2000
# Loss = 0.2019, Acc = 1.0000
# Epoch 5: Loss = 985.3669, Accuracy = 0.8457

# %%
save_file(model.state_dict(), 'arXiv_multi_class.safetensors')

# %%
# Testing loop
print('Testing...')

epoch_loss = 0.0
correct = 0
number = 0

model.eval()
with torch.no_grad():
    for i, batch in enumerate(test_loader):
        print(f'Testing batch {i + 1}/{len(test_loader)}')

        features, labels = batch
        optimiser.zero_grad()
        outputs = model(**features)
        logits = outputs.logits
        preds = torch.argmax(logits, dim=1)

        loss = loss_function(logits, labels)
        epoch_loss += loss.item()

        acc_labels = (labels == preds).sum().item()
        correct += acc_labels
        num_lab = labels.numel()
        number += num_lab
        acc = acc_labels / num_lab

        print(f"Loss = {loss.item():.4f}, Acc = {acc:.4f}")

print(f"Loss = {epoch_loss:.4f}, Accuracy = {correct / number:.4f}")
# Out:
# Testing...
# Testing batch 1/500
# Loss = 0.5258, Acc = 0.8750
# Testing batch 2/500
# Loss = 0.8026, Acc = 0.6250
# Testing batch 3/500
# Loss = 2.2231, Acc = 0.3750
# Testing batch 4/500
# Loss = 1.7356, Acc = 0.5000
# Testing batch 5/500
# Loss = 0.6652, Acc = 0.8750
# Testing batch 6/500
# Loss = 2.3263, Acc = 0.2500
# Testing batch 7/500
# Loss = 1.3173, Acc = 0.6250
# Testing batch 8/500
# Loss = 1.1849, Acc = 0.6250
# Testing batch 9/500
# Loss = 2.7510, Acc = 0.2500
# Testing batch 10/500
# Loss = 0.7739, Acc = 0.7500
# Testing batch 11/500
# Loss = 1.0772, Acc = 0.6250
# Testing batch 12/500
# Loss = 2.4410, Acc = 0.5000
# Testing batch 13/500
# Loss = 1.0691, Acc = 0.7500
# Testing batch 14/500
# Loss = 0.9057, Acc = 0.7500
# Testing batch 15/500
# Loss = 1.6623, Acc = 0.3750
# Testing batch 16/500
# Loss = 1.8628, Acc = 0.3750
# Testing batch 17/500
# Loss = 0.8815, Acc = 0.7500
# Testing batch 18/500
# Loss = 0.4630, Acc = 0.7500
# Testing batch 19/500
# Loss = 1.0615, Acc = 0.5000
# Testing batch 20/500
# Loss = 0.9111, Acc = 0.7500
# Testing batch 21/500
# Loss = 0.8198, Acc = 0.7500
# Testing batch 22/500
# Loss = 0.6488, Acc = 0.8750
# Testing batch 23/500
# Loss = 1.5397, Acc = 0.3750
# Testing batch 24/500
# Loss = 1.1085, Acc = 0.6250
# Testing batch 25/500
# Loss = 1.4198, Acc = 0.5000
# Testing batch 26/500
# Loss = 0.6762, Acc = 0.7500
# Testing batch 27/500
# Loss = 0.7175, Acc = 0.7500
# Testing batch 28/500
# Loss = 1.3219, Acc = 0.3750
# Testing batch 29/500
# Loss = 3.2103, Acc = 0.2500
# Testing batch 30/500
# Loss = 0.6614, Acc = 0.6250
# Testing batch 31/500
# Loss = 2.2874, Acc = 0.3750
# Testing batch 32/500
# Loss = 1.4317, Acc = 0.6250
# Testing batch 33/500
# Loss = 0.1827, Acc = 1.0000
# Testing batch 34/500
# Loss = 1.3177, Acc = 0.6250
# Testing batch 35/500
# Loss = 0.6674, Acc = 0.7500
# Testing batch 36/500
# Loss = 2.1266, Acc = 0.3750
# Testing batch 37/500
# Loss = 1.0260, Acc = 0.7500
# Testing batch 38/500
# Loss = 0.5774, Acc = 0.7500
# Testing batch 39/500
# Loss = 1.3205, Acc = 0.3750
# Testing batch 40/500
# Loss = 1.2633, Acc = 0.6250
# Testing batch 41/500
# Loss = 1.9953, Acc = 0.5000
# Testing batch 42/500
# Loss = 1.7508, Acc = 0.6250
# Testing batch 43/500
# Loss = 1.3175, Acc = 0.6250
# Testing batch 44/500
# Loss = 0.5331, Acc = 0.7500
# Testing batch 45/500
# Loss = 2.0439, Acc = 0.5000
# Testing batch 46/500
# Loss = 1.1178, Acc = 0.6250
# Testing batch 47/500
# Loss = 1.8487, Acc = 0.5000
# Testing batch 48/500
# Loss = 1.0310, Acc = 0.6250
# Testing batch 49/500
# Loss = 1.1207, Acc = 0.7500
# Testing batch 50/500
# Loss = 1.9876, Acc = 0.5000
# Testing batch 51/500
# Loss = 0.1124, Acc = 1.0000
# Testing batch 52/500
# Loss = 1.4298, Acc = 0.3750
# Testing batch 53/500
# Loss = 1.2726, Acc = 0.5000
# Testing batch 54/500
# Loss = 1.6941, Acc = 0.5000
# Testing batch 55/500
# Loss = 1.0330, Acc = 0.6250
# Testing batch 56/500
# Loss = 1.3736, Acc = 0.3750
# Testing batch 57/500
# Loss = 1.6363, Acc = 0.6250
# Testing batch 58/500
# Loss = 2.2990, Acc = 0.3750
# Testing batch 59/500
# Loss = 0.1289, Acc = 1.0000
# Testing batch 60/500
# Loss = 1.5817, Acc = 0.3750
# Testing batch 61/500
# Loss = 0.4813, Acc = 0.7500
# Testing batch 62/500
# Loss = 1.4092, Acc = 0.7500
# Testing batch 63/500
# Loss = 1.7363, Acc = 0.6250
# Testing batch 64/500
# Loss = 1.7240, Acc = 0.6250
# Testing batch 65/500
# Loss = 2.3767, Acc = 0.3750
# Testing batch 66/500
# Loss = 2.1876, Acc = 0.2500
# Testing batch 67/500
# Loss = 1.6846, Acc = 0.6250
# Testing batch 68/500
# Loss = 2.5127, Acc = 0.3750
# Testing batch 69/500
# Loss = 1.3453, Acc = 0.6250
# Testing batch 70/500
# Loss = 0.9424, Acc = 0.6250
# Testing batch 71/500
# Loss = 2.0641, Acc = 0.3750
# Testing batch 72/500
# Loss = 1.7871, Acc = 0.3750
# Testing batch 73/500
# Loss = 0.4267, Acc = 0.8750
# Testing batch 74/500
# Loss = 2.0775, Acc = 0.3750
# Testing batch 75/500
# Loss = 2.8169, Acc = 0.1250
# Testing batch 76/500
# Loss = 0.6769, Acc = 0.8750
# Testing batch 77/500
# Loss = 0.6686, Acc = 0.8750
# Testing batch 78/500
# Loss = 1.0830, Acc = 0.6250
# Testing batch 79/500
# Loss = 0.6612, Acc = 0.7500
# Testing batch 80/500
# Loss = 2.1419, Acc = 0.6250
# Testing batch 81/500
# Loss = 0.5308, Acc = 0.8750
# Testing batch 82/500
# Loss = 1.8644, Acc = 0.5000
# Testing batch 83/500
# Loss = 0.6646, Acc = 0.7500
# Testing batch 84/500
# Loss = 1.3388, Acc = 0.6250
# Testing batch 85/500
# Loss = 0.9982, Acc = 0.6250
# Testing batch 86/500
# Loss = 1.5866, Acc = 0.5000
# Testing batch 87/500
# Loss = 1.0159, Acc = 0.6250
# Testing batch 88/500
# Loss = 0.4824, Acc = 0.8750
# Testing batch 89/500
# Loss = 1.3094, Acc = 0.7500
# Testing batch 90/500
# Loss = 0.6439, Acc = 0.7500
# Testing batch 91/500
# Loss = 2.3142, Acc = 0.5000
# Testing batch 92/500
# Loss = 1.3704, Acc = 0.6250
# Testing batch 93/500
# Loss = 1.1534, Acc = 0.6250
# Testing batch 94/500
# Loss = 1.7012, Acc = 0.5000
# Testing batch 95/500
# Loss = 1.0090, Acc = 0.6250
# Testing batch 96/500
# Loss = 1.0516, Acc = 0.7500
# Testing batch 97/500
# Loss = 1.8162, Acc = 0.3750
# Testing batch 98/500
# Loss = 1.3284, Acc = 0.3750
# Testing batch 99/500
# Loss = 1.2449, Acc = 0.6250
# Testing batch 100/500
# Loss = 0.7394, Acc = 0.7500
# Testing batch 101/500
# Loss = 1.2303, Acc = 0.5000
# Testing batch 102/500
# Loss = 1.3178, Acc = 0.6250
# Testing batch 103/500
# Loss = 1.0421, Acc = 0.6250
# Testing batch 104/500
# Loss = 1.5650, Acc = 0.5000
# Testing batch 105/500
# Loss = 1.3364, Acc = 0.6250
# Testing batch 106/500
# Loss = 0.9216, Acc = 0.7500
# Testing batch 107/500
# Loss = 1.2577, Acc = 0.7500
# Testing batch 108/500
# Loss = 1.2182, Acc = 0.3750
# Testing batch 109/500
# Loss = 0.6454, Acc = 0.7500
# Testing batch 110/500
# Loss = 0.8273, Acc = 0.7500
# Testing batch 111/500
# Loss = 1.3423, Acc = 0.6250
# Testing batch 112/500
# Loss = 2.3452, Acc = 0.3750
# Testing batch 113/500
# Loss = 1.2594, Acc = 0.6250
# Testing batch 114/500
# Loss = 2.0163, Acc = 0.2500
# Testing batch 115/500
# Loss = 1.8333, Acc = 0.5000
# Testing batch 116/500
# Loss = 0.7539, Acc = 0.7500
# Testing batch 117/500
# Loss = 1.8898, Acc = 0.3750
# Testing batch 118/500
# Loss = 1.8544, Acc = 0.5000
# Testing batch 119/500
# Loss = 0.9118, Acc = 0.6250
# Testing batch 120/500
# Loss = 0.4648, Acc = 0.8750
# Testing batch 121/500
# Loss = 1.0856, Acc = 0.6250
# Testing batch 122/500
# Loss = 2.6658, Acc = 0.3750
# Testing batch 123/500
# Loss = 1.3763, Acc = 0.6250
# Testing batch 124/500
# Loss = 1.9207, Acc = 0.6250
# Testing batch 125/500
# Loss = 0.6097, Acc = 0.8750
# Testing batch 126/500
# Loss = 1.2490, Acc = 0.3750
# Testing batch 127/500
# Loss = 0.5249, Acc = 0.8750
# Testing batch 128/500
# Loss = 0.9117, Acc = 0.6250
# Testing batch 129/500
# Loss = 0.7651, Acc = 0.7500
# Testing batch 130/500
# Loss = 0.8072, Acc = 0.6250
# Testing batch 131/500
# Loss = 1.6534, Acc = 0.6250
# Testing batch 132/500
# Loss = 0.7111, Acc = 0.6250
# Testing batch 133/500
# Loss = 0.9271, Acc = 0.7500
# Testing batch 134/500
# Loss = 0.6975, Acc = 0.6250
# Testing batch 135/500
# Loss = 1.0098, Acc = 0.7500
# Testing batch 136/500
# Loss = 1.6302, Acc = 0.5000
# Testing batch 137/500
# Loss = 0.9726, Acc = 0.7500
# Testing batch 138/500
# Loss = 0.9354, Acc = 0.6250
# Testing batch 139/500
# Loss = 1.1033, Acc = 0.7500
# Testing batch 140/500
# Loss = 2.4060, Acc = 0.3750
# Testing batch 141/500
# Loss = 1.7071, Acc = 0.5000
# Testing batch 142/500
# Loss = 0.5228, Acc = 0.8750
# Testing batch 143/500
# Loss = 0.4998, Acc = 0.8750
# Testing batch 144/500
# Loss = 1.5149, Acc = 0.3750
# Testing batch 145/500
# Loss = 0.7319, Acc = 0.6250
# Testing batch 146/500
# Loss = 0.5912, Acc = 0.7500
# Testing batch 147/500
# Loss = 1.9538, Acc = 0.3750
# Testing batch 148/500
# Loss = 2.4438, Acc = 0.2500
# Testing batch 149/500
# Loss = 1.6320, Acc = 0.6250
# Testing batch 150/500
# Loss = 0.9993, Acc = 0.7500
# Testing batch 151/500
# Loss = 1.2873, Acc = 0.7500
# Testing batch 152/500
# Loss = 0.6122, Acc = 0.8750
# Testing batch 153/500
# Loss = 1.1640, Acc = 0.5000
# Testing batch 154/500
# Loss = 1.7501, Acc = 0.2500
# Testing batch 155/500
# Loss = 1.4030, Acc = 0.6250
# Testing batch 156/500
# Loss = 1.1232, Acc = 0.7500
# Testing batch 157/500
# Loss = 1.5188, Acc = 0.5000
# Testing batch 158/500
# Loss = 1.5684, Acc = 0.6250
# Testing batch 159/500
# Loss = 0.4617, Acc = 0.8750
# Testing batch 160/500
# Loss = 1.5335, Acc = 0.5000
# Testing batch 161/500
# Loss = 0.9879, Acc = 0.5000
# Testing batch 162/500
# Loss = 3.1123, Acc = 0.1250
# Testing batch 163/500
# Loss = 0.8552, Acc = 0.7500
# Testing batch 164/500
# Loss = 1.1971, Acc = 0.5000
# Testing batch 165/500
# Loss = 1.4370, Acc = 0.6250
# Testing batch 166/500
# Loss = 1.6207, Acc = 0.5000
# Testing batch 167/500
# Loss = 0.4054, Acc = 1.0000
# Testing batch 168/500
# Loss = 1.0589, Acc = 0.3750
# Testing batch 169/500
# Loss = 1.0666, Acc = 0.7500
# Testing batch 170/500
# Loss = 1.7407, Acc = 0.6250
# Testing batch 171/500
# Loss = 0.9190, Acc = 0.6250
# Testing batch 172/500
# Loss = 0.9291, Acc = 0.7500
# Testing batch 173/500
# Loss = 1.0525, Acc = 0.7500
# Testing batch 174/500
# Loss = 1.5000, Acc = 0.5000
# Testing batch 175/500
# Loss = 1.1666, Acc = 0.6250
# Testing batch 176/500
# Loss = 2.1207, Acc = 0.3750
# Testing batch 177/500
# Loss = 1.8773, Acc = 0.3750
# Testing batch 178/500
# Loss = 1.4453, Acc = 0.6250
# Testing batch 179/500
# Loss = 1.7026, Acc = 0.3750
# Testing batch 180/500
# Loss = 1.2867, Acc = 0.5000
# Testing batch 181/500
# Loss = 1.6045, Acc = 0.5000
# Testing batch 182/500
# Loss = 2.2832, Acc = 0.2500
# Testing batch 183/500
# Loss = 1.3787, Acc = 0.6250
# Testing batch 184/500
# Loss = 1.2207, Acc = 0.6250
# Testing batch 185/500
# Loss = 0.6807, Acc = 0.8750
# Testing batch 186/500
# Loss = 1.8768, Acc = 0.3750
# Testing batch 187/500
# Loss = 0.7457, Acc = 0.7500
# Testing batch 188/500
# Loss = 1.6375, Acc = 0.3750
# Testing batch 189/500
# Loss = 0.3096, Acc = 0.8750
# Testing batch 190/500
# Loss = 1.3300, Acc = 0.5000
# Testing batch 191/500
# Loss = 1.6001, Acc = 0.3750
# Testing batch 192/500
# Loss = 0.3677, Acc = 0.8750
# Testing batch 193/500
# Loss = 2.4041, Acc = 0.3750
# Testing batch 194/500
# Loss = 2.6185, Acc = 0.1250
# Testing batch 195/500
# Loss = 0.2271, Acc = 1.0000
# Testing batch 196/500
# Loss = 2.3773, Acc = 0.3750
# Testing batch 197/500
# Loss = 1.0808, Acc = 0.6250
# Testing batch 198/500
# Loss = 0.5630, Acc = 0.7500
# Testing batch 199/500
# Loss = 1.6490, Acc = 0.5000
# Testing batch 200/500
# Loss = 1.1679, Acc = 0.7500
# Testing batch 201/500
# Loss = 1.4477, Acc = 0.7500
# Testing batch 202/500
# Loss = 2.3622, Acc = 0.3750
# Testing batch 203/500
# Loss = 1.2849, Acc = 0.6250
# Testing batch 204/500
# Loss = 0.7833, Acc = 0.5000
# Testing batch 205/500
# Loss = 1.8521, Acc = 0.3750
# Testing batch 206/500
# Loss = 0.7397, Acc = 0.7500
# Testing batch 207/500
# Loss = 1.6477, Acc = 0.3750
# Testing batch 208/500
# Loss = 1.3090, Acc = 0.6250
# Testing batch 209/500
# Loss = 1.3642, Acc = 0.5000
# Testing batch 210/500
# Loss = 0.6190, Acc = 0.8750
# Testing batch 211/500
# Loss = 1.8455, Acc = 0.5000
# Testing batch 212/500
# Loss = 1.6734, Acc = 0.5000
# Testing batch 213/500
# Loss = 1.0806, Acc = 0.6250
# Testing batch 214/500
# Loss = 1.3621, Acc = 0.5000
# Testing batch 215/500
# Loss = 1.3769, Acc = 0.6250
# Testing batch 216/500
# Loss = 1.8056, Acc = 0.3750
# Testing batch 217/500
# Loss = 0.6678, Acc = 0.6250
# Testing batch 218/500
# Loss = 0.8871, Acc = 0.7500
# Testing batch 219/500
# Loss = 1.6309, Acc = 0.6250
# Testing batch 220/500
# Loss = 2.0223, Acc = 0.5000
# Testing batch 221/500
# Loss = 1.2159, Acc = 0.5000
# Testing batch 222/500
# Loss = 1.5884, Acc = 0.3750
# Testing batch 223/500
# Loss = 1.4196, Acc = 0.5000
# Testing batch 224/500
# Loss = 1.4919, Acc = 0.6250
# Testing batch 225/500
# Loss = 0.7405, Acc = 0.7500
# Testing batch 226/500
# Loss = 1.0184, Acc = 0.6250
# Testing batch 227/500
# Loss = 0.9900, Acc = 0.5000
# Testing batch 228/500
# Loss = 0.4679, Acc = 0.8750
# Testing batch 229/500
# Loss = 1.2592, Acc = 0.6250
# Testing batch 230/500
# Loss = 1.0559, Acc = 0.6250
# Testing batch 231/500
# Loss = 2.0649, Acc = 0.5000
# Testing batch 232/500
# Loss = 1.6067, Acc = 0.5000
# Testing batch 233/500
# Loss = 1.4390, Acc = 0.5000
# Testing batch 234/500
# Loss = 2.0379, Acc = 0.3750
# Testing batch 235/500
# Loss = 2.1863, Acc = 0.3750
# Testing batch 236/500
# Loss = 0.5742, Acc = 0.7500
# Testing batch 237/500
# Loss = 0.3823, Acc = 0.7500
# Testing batch 238/500
# Loss = 2.7144, Acc = 0.2500
# Testing batch 239/500
# Loss = 1.9015, Acc = 0.3750
# Testing batch 240/500
# Loss = 0.9202, Acc = 0.7500
# Testing batch 241/500
# Loss = 0.3358, Acc = 0.8750
# Testing batch 242/500
# Loss = 1.5269, Acc = 0.7500
# Testing batch 243/500
# Loss = 1.5362, Acc = 0.6250
# Testing batch 244/500
# Loss = 1.1917, Acc = 0.7500
# Testing batch 245/500
# Loss = 0.7460, Acc = 0.8750
# Testing batch 246/500
# Loss = 1.3873, Acc = 0.5000
# Testing batch 247/500
# Loss = 1.1858, Acc = 0.5000
# Testing batch 248/500
# Loss = 0.6029, Acc = 0.8750
# Testing batch 249/500
# Loss = 2.5900, Acc = 0.2500
# Testing batch 250/500
# Loss = 1.4159, Acc = 0.5000
# Testing batch 251/500
# Loss = 2.8800, Acc = 0.2500
# Testing batch 252/500
# Loss = 1.2803, Acc = 0.7500
# Testing batch 253/500
# Loss = 1.2585, Acc = 0.5000
# Testing batch 254/500
# Loss = 0.8801, Acc = 0.6250
# Testing batch 255/500
# Loss = 1.3201, Acc = 0.5000
# Testing batch 256/500
# Loss = 1.2010, Acc = 0.6250
# Testing batch 257/500
# Loss = 0.6140, Acc = 0.7500
# Testing batch 258/500
# Loss = 0.5035, Acc = 0.8750
# Testing batch 259/500
# Loss = 1.1200, Acc = 0.7500
# Testing batch 260/500
# Loss = 1.3598, Acc = 0.7500
# Testing batch 261/500
# Loss = 1.6226, Acc = 0.5000
# Testing batch 262/500
# Loss = 0.6570, Acc = 0.7500
# Testing batch 263/500
# Loss = 1.8587, Acc = 0.3750
# Testing batch 264/500
# Loss = 0.8191, Acc = 0.6250
# Testing batch 265/500
# Loss = 0.9659, Acc = 0.6250
# Testing batch 266/500
# Loss = 1.1079, Acc = 0.6250
# Testing batch 267/500
# Loss = 0.9863, Acc = 0.6250
# Testing batch 268/500
# Loss = 2.5559, Acc = 0.3750
# Testing batch 269/500
# Loss = 1.1687, Acc = 0.6250
# Testing batch 270/500
# Loss = 0.3715, Acc = 0.8750
# Testing batch 271/500
# Loss = 0.0695, Acc = 1.0000
# Testing batch 272/500
# Loss = 1.3036, Acc = 0.6250
# Testing batch 273/500
# Loss = 2.0116, Acc = 0.3750
# Testing batch 274/500
# Loss = 1.5497, Acc = 0.6250
# Testing batch 275/500
# Loss = 0.8420, Acc = 0.8750
# Testing batch 276/500
# Loss = 0.5905, Acc = 0.7500
# Testing batch 277/500
# Loss = 0.8419, Acc = 0.7500
# Testing batch 278/500
# Loss = 2.5367, Acc = 0.3750
# Testing batch 279/500
# Loss = 1.5158, Acc = 0.6250
# Testing batch 280/500
# Loss = 1.5424, Acc = 0.5000
# Testing batch 281/500
# Loss = 1.2321, Acc = 0.6250
# Testing batch 282/500
# Loss = 0.9837, Acc = 0.7500
# Testing batch 283/500
# Loss = 1.4230, Acc = 0.6250
# Testing batch 284/500
# Loss = 0.8019, Acc = 0.7500
# Testing batch 285/500
# Loss = 1.8221, Acc = 0.3750
# Testing batch 286/500
# Loss = 2.8273, Acc = 0.3750
# Testing batch 287/500
# Loss = 0.7910, Acc = 0.6250
# Testing batch 288/500
# Loss = 1.3430, Acc = 0.6250
# Testing batch 289/500
# Loss = 1.5242, Acc = 0.6250
# Testing batch 290/500
# Loss = 1.8136, Acc = 0.6250
# Testing batch 291/500
# Loss = 1.2642, Acc = 0.3750
# Testing batch 292/500
# Loss = 0.9874, Acc = 0.6250
# Testing batch 293/500
# Loss = 1.4889, Acc = 0.5000
# Testing batch 294/500
# Loss = 0.4405, Acc = 0.7500
# Testing batch 295/500
# Loss = 1.3293, Acc = 0.5000
# Testing batch 296/500
# Loss = 1.0753, Acc = 0.6250
# Testing batch 297/500
# Loss = 2.1109, Acc = 0.2500
# Testing batch 298/500
# Loss = 1.1515, Acc = 0.7500
# Testing batch 299/500
# Loss = 1.3195, Acc = 0.5000
# Testing batch 300/500
# Loss = 0.7382, Acc = 0.8750
# Testing batch 301/500
# Loss = 2.0340, Acc = 0.6250
# Testing batch 302/500
# Loss = 1.2394, Acc = 0.5000
# Testing batch 303/500
# Loss = 2.2703, Acc = 0.3750
# Testing batch 304/500
# Loss = 2.2441, Acc = 0.5000
# Testing batch 305/500
# Loss = 0.8853, Acc = 0.7500
# Testing batch 306/500
# Loss = 1.4204, Acc = 0.7500
# Testing batch 307/500
# Loss = 1.2636, Acc = 0.6250
# Testing batch 308/500
# Loss = 0.3648, Acc = 0.7500
# Testing batch 309/500
# Loss = 0.8236, Acc = 0.6250
# Testing batch 310/500
# Loss = 0.6489, Acc = 0.7500
# Testing batch 311/500
# Loss = 0.4514, Acc = 0.7500
# Testing batch 312/500
# Loss = 0.4100, Acc = 1.0000
# Testing batch 313/500
# Loss = 0.3955, Acc = 0.7500
# Testing batch 314/500
# Loss = 1.8032, Acc = 0.5000
# Testing batch 315/500
# Loss = 1.3534, Acc = 0.6250
# Testing batch 316/500
# Loss = 2.1199, Acc = 0.5000
# Testing batch 317/500
# Loss = 0.8863, Acc = 0.7500
# Testing batch 318/500
# Loss = 0.6501, Acc = 0.8750
# Testing batch 319/500
# Loss = 0.9395, Acc = 0.6250
# Testing batch 320/500
# Loss = 1.0874, Acc = 0.7500
# Testing batch 321/500
# Loss = 1.3168, Acc = 0.6250
# Testing batch 322/500
# Loss = 0.2381, Acc = 0.8750
# Testing batch 323/500
# Loss = 1.4429, Acc = 0.3750
# Testing batch 324/500
# Loss = 1.5052, Acc = 0.6250
# Testing batch 325/500
# Loss = 0.9775, Acc = 0.6250
# Testing batch 326/500
# Loss = 0.4803, Acc = 0.8750
# Testing batch 327/500
# Loss = 1.0927, Acc = 0.6250
# Testing batch 328/500
# Loss = 0.8179, Acc = 0.7500
# Testing batch 329/500
# Loss = 1.0270, Acc = 0.6250
# Testing batch 330/500
# Loss = 1.7132, Acc = 0.5000
# Testing batch 331/500
# Loss = 1.3458, Acc = 0.6250
# Testing batch 332/500
# Loss = 1.9337, Acc = 0.5000
# Testing batch 333/500
# Loss = 0.2358, Acc = 1.0000
# Testing batch 334/500
# Loss = 1.4657, Acc = 0.6250
# Testing batch 335/500
# Loss = 1.5155, Acc = 0.5000
# Testing batch 336/500
# Loss = 1.1806, Acc = 0.7500
# Testing batch 337/500
# Loss = 1.2348, Acc = 0.6250
# Testing batch 338/500
# Loss = 2.2607, Acc = 0.3750
# Testing batch 339/500
# Loss = 2.0804, Acc = 0.6250
# Testing batch 340/500
# Loss = 0.4436, Acc = 0.7500
# Testing batch 341/500
# Loss = 2.6617, Acc = 0.2500
# Testing batch 342/500
# Loss = 1.1150, Acc = 0.6250
# Testing batch 343/500
# Loss = 1.8575, Acc = 0.3750
# Testing batch 344/500
# Loss = 1.2543, Acc = 0.5000
# Testing batch 345/500
# Loss = 1.7596, Acc = 0.6250
# Testing batch 346/500
# Loss = 0.6419, Acc = 0.7500
# Testing batch 347/500
# Loss = 1.1174, Acc = 0.7500
# Testing batch 348/500
# Loss = 0.9146, Acc = 0.6250
# Testing batch 349/500
# Loss = 1.3982, Acc = 0.3750
# Testing batch 350/500
# Loss = 0.7219, Acc = 0.7500
# Testing batch 351/500
# Loss = 1.3426, Acc = 0.6250
# Testing batch 352/500
# Loss = 1.2533, Acc = 0.7500
# Testing batch 353/500
# Loss = 1.5036, Acc = 0.5000
# Testing batch 354/500
# Loss = 0.6231, Acc = 0.8750
# Testing batch 355/500
# Loss = 1.6839, Acc = 0.5000
# Testing batch 356/500
# Loss = 1.1369, Acc = 0.6250
# Testing batch 357/500
# Loss = 1.1687, Acc = 0.7500
# Testing batch 358/500
# Loss = 1.0493, Acc = 0.6250
# Testing batch 359/500
# Loss = 1.5659, Acc = 0.5000
# Testing batch 360/500
# Loss = 0.9704, Acc = 0.6250
# Testing batch 361/500
# Loss = 1.3107, Acc = 0.6250
# Testing batch 362/500
# Loss = 0.8712, Acc = 0.7500
# Testing batch 363/500
# Loss = 0.8563, Acc = 0.7500
# Testing batch 364/500
# Loss = 1.5037, Acc = 0.5000
# Testing batch 365/500
# Loss = 1.8022, Acc = 0.3750
# Testing batch 366/500
# Loss = 1.3180, Acc = 0.6250
# Testing batch 367/500
# Loss = 2.4157, Acc = 0.3750
# Testing batch 368/500
# Loss = 1.2251, Acc = 0.6250
# Testing batch 369/500
# Loss = 1.9247, Acc = 0.5000
# Testing batch 370/500
# Loss = 1.2493, Acc = 0.6250
# Testing batch 371/500
# Loss = 1.0444, Acc = 0.5000
# Testing batch 372/500
# Loss = 0.7613, Acc = 0.7500
# Testing batch 373/500
# Loss = 1.6322, Acc = 0.5000
# Testing batch 374/500
# Loss = 0.5078, Acc = 1.0000
# Testing batch 375/500
# Loss = 1.2688, Acc = 0.7500
# Testing batch 376/500
# Loss = 0.9110, Acc = 0.7500
# Testing batch 377/500
# Loss = 2.0001, Acc = 0.5000
# Testing batch 378/500
# Loss = 0.9604, Acc = 0.6250
# Testing batch 379/500
# Loss = 0.8931, Acc = 0.6250
# Testing batch 380/500
# Loss = 0.9054, Acc = 0.6250
# Testing batch 381/500
# Loss = 0.4288, Acc = 0.8750
# Testing batch 382/500
# Loss = 1.4502, Acc = 0.6250
# Testing batch 383/500
# Loss = 1.0380, Acc = 0.6250
# Testing batch 384/500
# Loss = 0.7451, Acc = 0.7500
# Testing batch 385/500
# Loss = 0.6484, Acc = 0.7500
# Testing batch 386/500
# Loss = 1.2595, Acc = 0.6250
# Testing batch 387/500
# Loss = 1.7201, Acc = 0.6250
# Testing batch 388/500
# Loss = 1.2619, Acc = 0.5000
# Testing batch 389/500
# Loss = 1.1150, Acc = 0.7500
# Testing batch 390/500
# Loss = 2.6321, Acc = 0.3750
# Testing batch 391/500
# Loss = 1.5654, Acc = 0.3750
# Testing batch 392/500
# Loss = 1.6073, Acc = 0.5000
# Testing batch 393/500
# Loss = 0.2503, Acc = 1.0000
# Testing batch 394/500
# Loss = 1.0171, Acc = 0.6250
# Testing batch 395/500
# Loss = 1.5677, Acc = 0.3750
# Testing batch 396/500
# Loss = 0.7318, Acc = 0.7500
# Testing batch 397/500
# Loss = 0.9457, Acc = 0.8750
# Testing batch 398/500
# Loss = 1.3322, Acc = 0.6250
# Testing batch 399/500
# Loss = 2.0357, Acc = 0.5000
# Testing batch 400/500
# Loss = 2.4337, Acc = 0.2500
# Testing batch 401/500
# Loss = 0.9174, Acc = 0.6250
# Testing batch 402/500
# Loss = 1.0638, Acc = 0.6250
# Testing batch 403/500
# Loss = 1.1745, Acc = 0.5000
# Testing batch 404/500
# Loss = 2.3271, Acc = 0.3750
# Testing batch 405/500
# Loss = 0.8522, Acc = 0.6250
# Testing batch 406/500
# Loss = 0.7101, Acc = 0.7500
# Testing batch 407/500
# Loss = 0.9377, Acc = 0.7500
# Testing batch 408/500
# Loss = 1.3681, Acc = 0.6250
# Testing batch 409/500
# Loss = 0.5287, Acc = 0.8750
# Testing batch 410/500
# Loss = 1.0325, Acc = 0.6250
# Testing batch 411/500
# Loss = 2.1033, Acc = 0.3750
# Testing batch 412/500
# Loss = 0.6291, Acc = 0.7500
# Testing batch 413/500
# Loss = 0.8901, Acc = 0.7500
# Testing batch 414/500
# Loss = 0.8507, Acc = 0.6250
# Testing batch 415/500
# Loss = 1.5228, Acc = 0.6250
# Testing batch 416/500
# Loss = 0.8939, Acc = 0.5000
# Testing batch 417/500
# Loss = 1.9262, Acc = 0.6250
# Testing batch 418/500
# Loss = 0.6327, Acc = 0.7500
# Testing batch 419/500
# Loss = 1.6765, Acc = 0.5000
# Testing batch 420/500
# Loss = 1.9716, Acc = 0.5000
# Testing batch 421/500
# Loss = 0.2903, Acc = 0.8750
# Testing batch 422/500
# Loss = 1.2357, Acc = 0.6250
# Testing batch 423/500
# Loss = 0.6648, Acc = 0.8750
# Testing batch 424/500
# Loss = 0.9979, Acc = 0.7500
# Testing batch 425/500
# Loss = 2.5581, Acc = 0.3750
# Testing batch 426/500
# Loss = 0.8666, Acc = 0.5000
# Testing batch 427/500
# Loss = 1.6050, Acc = 0.5000
# Testing batch 428/500
# Loss = 1.4218, Acc = 0.3750
# Testing batch 429/500
# Loss = 1.7135, Acc = 0.5000
# Testing batch 430/500
# Loss = 1.4731, Acc = 0.6250
# Testing batch 431/500
# Loss = 1.3310, Acc = 0.5000
# Testing batch 432/500
# Loss = 0.8275, Acc = 0.6250
# Testing batch 433/500
# Loss = 2.2948, Acc = 0.3750
# Testing batch 434/500
# Loss = 0.3827, Acc = 0.8750
# Testing batch 435/500
# Loss = 1.1301, Acc = 0.6250
# Testing batch 436/500
# Loss = 0.8549, Acc = 0.7500
# Testing batch 437/500
# Loss = 1.3991, Acc = 0.6250
# Testing batch 438/500
# Loss = 1.3314, Acc = 0.6250
# Testing batch 439/500
# Loss = 0.6579, Acc = 0.7500
# Testing batch 440/500
# Loss = 0.8947, Acc = 0.7500
# Testing batch 441/500
# Loss = 1.3479, Acc = 0.5000
# Testing batch 442/500
# Loss = 1.4878, Acc = 0.6250
# Testing batch 443/500
# Loss = 0.6978, Acc = 0.6250
# Testing batch 444/500
# Loss = 1.4243, Acc = 0.6250
# Testing batch 445/500
# Loss = 0.8263, Acc = 0.7500
# Testing batch 446/500
# Loss = 0.9455, Acc = 0.6250
# Testing batch 447/500
# Loss = 2.0120, Acc = 0.5000
# Testing batch 448/500
# Loss = 0.8366, Acc = 0.8750
# Testing batch 449/500
# Loss = 1.8579, Acc = 0.6250
# Testing batch 450/500
# Loss = 1.1378, Acc = 0.6250
# Testing batch 451/500
# Loss = 1.5951, Acc = 0.5000
# Testing batch 452/500
# Loss = 1.0000, Acc = 0.7500
# Testing batch 453/500
# Loss = 0.7821, Acc = 0.6250
# Testing batch 454/500
# Loss = 1.2805, Acc = 0.5000
# Testing batch 455/500
# Loss = 0.5804, Acc = 0.7500
# Testing batch 456/500
# Loss = 2.1221, Acc = 0.6250
# Testing batch 457/500
# Loss = 1.0839, Acc = 0.7500
# Testing batch 458/500
# Loss = 1.0336, Acc = 0.6250
# Testing batch 459/500
# Loss = 1.2419, Acc = 0.5000
# Testing batch 460/500
# Loss = 0.7580, Acc = 0.7500
# Testing batch 461/500
# Loss = 1.1542, Acc = 0.5000
# Testing batch 462/500
# Loss = 1.8619, Acc = 0.5000
# Testing batch 463/500
# Loss = 2.1259, Acc = 0.3750
# Testing batch 464/500
# Loss = 2.4231, Acc = 0.2500
# Testing batch 465/500
# Loss = 1.0339, Acc = 0.5000
# Testing batch 466/500
# Loss = 1.2658, Acc = 0.6250
# Testing batch 467/500
# Loss = 1.0980, Acc = 0.6250
# Testing batch 468/500
# Loss = 1.7202, Acc = 0.5000
# Testing batch 469/500
# Loss = 1.2078, Acc = 0.7500
# Testing batch 470/500
# Loss = 1.1185, Acc = 0.7500
# Testing batch 471/500
# Loss = 2.1270, Acc = 0.3750
# Testing batch 472/500
# Loss = 1.1280, Acc = 0.5000
# Testing batch 473/500
# Loss = 1.0165, Acc = 0.7500
# Testing batch 474/500
# Loss = 2.6814, Acc = 0.2500
# Testing batch 475/500
# Loss = 1.6748, Acc = 0.5000
# Testing batch 476/500
# Loss = 0.8236, Acc = 0.6250
# Testing batch 477/500
# Loss = 1.0283, Acc = 0.6250
# Testing batch 478/500
# Loss = 2.2806, Acc = 0.5000
# Testing batch 479/500
# Loss = 1.0559, Acc = 0.6250
# Testing batch 480/500
# Loss = 0.9017, Acc = 0.7500
# Testing batch 481/500
# Loss = 1.3048, Acc = 0.5000
# Testing batch 482/500
# Loss = 1.9680, Acc = 0.5000
# Testing batch 483/500
# Loss = 1.3899, Acc = 0.6250
# Testing batch 484/500
# Loss = 1.1361, Acc = 0.6250
# Testing batch 485/500
# Loss = 1.8290, Acc = 0.5000
# Testing batch 486/500
# Loss = 1.4991, Acc = 0.3750
# Testing batch 487/500
# Loss = 1.2589, Acc = 0.5000
# Testing batch 488/500
# Loss = 1.9385, Acc = 0.5000
# Testing batch 489/500
# Loss = 1.0113, Acc = 0.7500
# Testing batch 490/500
# Loss = 0.8223, Acc = 0.6250
# Testing batch 491/500
# Loss = 1.9229, Acc = 0.5000
# Testing batch 492/500
# Loss = 0.4098, Acc = 0.8750
# Testing batch 493/500
# Loss = 1.2043, Acc = 0.5000
# Testing batch 494/500
# Loss = 2.0958, Acc = 0.2500
# Testing batch 495/500
# Loss = 1.4865, Acc = 0.3750
# Testing batch 496/500
# Loss = 0.9716, Acc = 0.7500
# Testing batch 497/500
# Loss = 2.4878, Acc = 0.5000
# Testing batch 498/500
# Loss = 0.3856, Acc = 1.0000
# Testing batch 499/500
# Loss = 0.9449, Acc = 0.6250
# Testing batch 500/500
# Loss = 2.2017, Acc = 0.3750
# Loss = 648.4915, Accuracy = 0.6035

# %%
# Define a function that classifies new titles
def classify(s):
    # Tokenize input string
    tok_title = tokenizer(
            s,
            return_tensors='pt',
            padding=True,
            truncation=True,
            max_length=max_length
        )

    # Run model on tokenized input
    model.eval()
    with torch.no_grad():
        outputs = model(**tok_title)
        logits = outputs.logits
        preds = torch.argmax(logits, dim=1)

        print(f"class: {id2label[preds[0].item()]}")

# %%
classify('Pseudo-algebroids for categorical rings')
# Out:
# class: math.AG

# %%
classify('Free electron trajectories in graphene')
# Out:
# class: cond-mat.mes-hall

# %%
classify('Equivariant DW Invariants from Physical Fluxes')
# Out:
# class: hep-th
